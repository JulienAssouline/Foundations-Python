# %%
import pandas as pd
# %matplotlib inline

# %%
# I used Tabula to convert this into a csv.
FOIL = pd.read_csv("tabula-FOIL_2017_32_Resp_Doc.csv", error_bad_lines=False)
# Out:
# b'Skipping line 6441: expected 1 fields, saw 2\nSkipping line 6442: expected 1 fields, saw 2\nSkipping line 6443: expected 1 fields, saw 2\nSkipping line 6444: expected 1 fields, saw 2\nSkipping line 6445: expected 1 fields, saw 2\nSkipping line 6446: expected 1 fields, saw 2\nSkipping line 6447: expected 1 fields, saw 2\nSkipping line 6448: expected 1 fields, saw 2\nSkipping line 6449: expected 1 fields, saw 2\nSkipping line 6450: expected 1 fields, saw 2\nSkipping line 6451: expected 1 fields, saw 2\nSkipping line 6452: expected 1 fields, saw 2\nSkipping line 6453: expected 1 fields, saw 2\nSkipping line 6454: expected 1 fields, saw 2\nSkipping line 6455: expected 1 fields, saw 2\nSkipping line 6456: expected 1 fields, saw 2\nSkipping line 6457: expected 1 fields, saw 2\nSkipping line 6458: expected 1 fields, saw 2\nSkipping line 6459: expected 1 fields, saw 2\nSkipping line 6460: expected 1 fields, saw 2\nSkipping line 6461: expected 1 fields, saw 2\nSkipping line 6462: expected 1
# ...

# %%
FOIL
# Out:
#                      Employee
# 0             Abate, Arnold M
# 1            Abbott, Sharon L
# 2            Abbott, Thomas J
# 3            Abdella, Mubarak
# 4             ABRAHAM, RANI A
# 5          Abrahamson, Mark E
# 6              Abrams, Drew P
# 7            Abuawad, Ahmad K
# 8            Abuawad, Saleh K
# 9               Aceto, John V
# 10                Acklin, Roy
# 11           Adams, Charles G
# 12                Adams, Erin
# 13              Adams, Ross D
# 14            Adams, Thomas H
# 15          Addepalli, Venu P
# 16           Adewunmi, Stella
# 17              Adey, Jason R
# 18        Adiletta, Kristin A
# 19            Adkins, David L
# 20            Advani, Muskaan
# 21        Agen, Christopher G
# 22            Aghanenu, Ngozi
# 23    Agiovlasitis, Michael T
# 24              Agnew, Adam C
# 25           Agnew, Charles E
# 26          Agresta, Joseph A
# 27            Agyare, Loretha
# 28              Ahmad, Rana K
# 29               Ahmad, Umair
# ...

# %%
## here the PDF was an image, so I converted it to a png, and then converted it to text in the command line. 
US_Department_of_Justice = pd.read_csv("output.txt.txt", error_bad_lines=False)
US_Department_of_Justice.head()
# Out:
# b'Skipping line 7: expected 1 fields, saw 2\nSkipping line 9: expected 1 fields, saw 2\nSkipping line 17: expected 1 fields, saw 2\nSkipping line 20: expected 1 fields, saw 2\nSkipping line 48: expected 1 fields, saw 2\nSkipping line 49: expected 1 fields, saw 2\nSkipping line 52: expected 1 fields, saw 2\nSkipping line 55: expected 1 fields, saw 2\nSkipping line 57: expected 1 fields, saw 4\nSkipping line 60: expected 1 fields, saw 2\nSkipping line 61: expected 1 fields, saw 2\n'
#         U.S. Department of Justice
# 0  Federal Bureau of lnvesti ation
# 1                 MR. MICHAEL BEST
# 2                    MUCKROCK NEWS
# 3                    DEPT MR 24028
# 4             411A HIGHLAND AVENUE

# %%
# For the rest of these I used tabula to convert them into csvs or excel files
threatened_animals = pd.read_csv("species threatened.csv", error_bad_lines=False)
threatened_animals.head()
# Out:
# b'Skipping line 13: expected 15 fields, saw 16\nSkipping line 14: expected 15 fields, saw 16\nSkipping line 15: expected 15 fields, saw 16\nSkipping line 16: expected 15 fields, saw 16\nSkipping line 17: expected 15 fields, saw 16\nSkipping line 18: expected 15 fields, saw 16\nSkipping line 19: expected 15 fields, saw 16\nSkipping line 20: expected 15 fields, saw 16\nSkipping line 21: expected 15 fields, saw 16\nSkipping line 22: expected 15 fields, saw 16\nSkipping line 23: expected 15 fields, saw 16\nSkipping line 24: expected 15 fields, saw 16\nSkipping line 25: expected 15 fields, saw 16\nSkipping line 26: expected 15 fields, saw 16\nSkipping line 27: expected 15 fields, saw 16\nSkipping line 28: expected 15 fields, saw 16\nSkipping line 29: expected 15 fields, saw 16\nSkipping line 30: expected 15 fields, saw 16\nSkipping line 31: expected 15 fields, saw 16\nSkipping line 32: expected 15 fields, saw 16\nSkipping line 33: expected 15 fields, saw 16\nSkipping line 34: expected 15 
# ...

# %%
threatened_animals["Critically Endangered (CR)"].str.split(" ", 4, expand = True)
# Out:
#         0      1      2      3
# 0    2006   2007   2008   2009
# 1     162    163    188    188
# 2     181    189    190    192
# 3      73     79     86     93
# 4     442    441    475    484
# 5     253    254    289    306
# 6      68     69     70     89
# 7     265    268    268    291
# 8      84     86     99     99
# 9   1,541  1,569  1,575  1,577
# 10      2      2      2      2

# %%
threatened_animals
# Out:
#              Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                 Group    1996/98       2000       2002       2003
# 1               Mammals        169        180        181        184
# 2                 Birds        168        182        182        182
# 3              Reptiles         41         56         55         57
# 4            Amphibians         18         25         30         30
# 5                Fishes        157        156        157        162
# 6               Insects         44         45         46         46
# 7              Molluscs        257        222        222        250
# 8   Other Invertebrates         57         59         59         61
# 9                Plants        909      1,014      1,046      1,276
# 10     Fungi & Protists          0          0          0          1
#
#    Unnamed: 5 Critically Endangered (CR) Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        2004        2006 2007 2008 2009       2010       2011       2012
# ...

# %%
xls = pd.ExcelFile("Endangered animals (1).xlsx")
df1 = xls.parse('Sheet1')
df2 = xls.parse('Sheet2')
df3 = xls.parse('Sheet3')

# %%
df1["2006"] = df1["2006 2007 2008 2009"].str.split(" ", 4, expand=True)[0]
df1["2007"] = df1["2006 2007 2008 2009"].str.split(" ", 4, expand=True)[1]
df1["2008"] = df1["2006 2007 2008 2009"].str.split(" ", 4, expand=True)[2]
df1["2009"] = df1["2006 2007 2008 2009"].str.split(" ", 4, expand=True)[3]

# %%
df1.drop("2006 2007 2008 2009", 1, inplace=True)

# %%
df1.head()
# Out:
#   Critically Endangered (CR)  1996/98  2000  2002  2003  2004  2010  2011  \
# 0                    Mammals      169   180   181   184   162   188   194
# 1                      Birds      168   182   182   182   179   190   189
# 2                   Reptiles       41    56    55    57    64   106   137
# 3                 Amphibians       18    25    30    30   413   486   498
# 4                     Fishes      157   156   157   162   171   376   414
#
#    2012  2013  2014  2015  2016  2017 2006 2007 2008 2009
# 0   196   196   213   209   204   203  162  163  188  188
# 1   197   198   213   218   225   225  181  189  190  192
# 2   144   164   174   180   237   240   73   79   86   93
# 3   509   520   518   528   546   545  442  441  475  484
# 4   415   413   443   446   461   461  253  254  289  306

# %%
df1 = df1.melt(var_name = "Year", value_name = "count", id_vars=["Critically Endangered (CR)"])
df1.head()
# Out:
#   Critically Endangered (CR)     Year count
# 0                    Mammals  1996/98   169
# 1                      Birds  1996/98   168
# 2                   Reptiles  1996/98    41
# 3                 Amphibians  1996/98    18
# 4                     Fishes  1996/98   157

# %%
df1["Year"] = df1["Year"].astype(str).str.replace("/98", "")

# %%
df1["Year"] = df1["Year"].astype(int)

# %%
df1["count"] = df1["count"].astype(str).str.replace(",", "")
df1.head()
# Out:
#   Critically Endangered (CR)  Year count
# 0                    Mammals  1996   169
# 1                      Birds  1996   168
# 2                   Reptiles  1996    41
# 3                 Amphibians  1996    18
# 4                     Fishes  1996   157

# %%
df1["count"] = df1["count"].astype(int)
df1.sort_values(by = "Year", ascending = True, inplace = True)

# %%
df1.tail()
# Out:
#     Critically Endangered (CR)  Year  count
# 124                     Fishes  2017    461
# 125                    Insects  2017    226
# 126                   Molluscs  2017    586
# 128                     Plants  2017   2509
# 129           Fungi & Protists  2017      8

# %%
df1.columns = ["Critically_Endangered", "Year", "count"]
df1.head()
# Out:
#   Critically_Endangered  Year  count
# 0               Mammals  1996    169
# 1                 Birds  1996    168
# 2              Reptiles  1996     41
# 3            Amphibians  1996     18
# 4                Fishes  1996    157

# %%
df1.to_csv("Critically Endangered.csv")

# %%
df2["2007"] = df2["2007 2008 2009"].str.split(" ", 4, expand=True)[0]
df2["2008"] = df2["2007 2008 2009"].str.split(" ", 4, expand=True)[1]
df2["2009"] = df2["2007 2008 2009"].str.split(" ", 4, expand=True)[2]

# %%
df2.drop("2007 2008 2009", 1, inplace=True)
df2.head()
# Out:
#   Endangered (EN)  1996/98  2000  2002  2003  2004  2006  2010  2011  2012  \
# 0         Mammals      315   340   339   337   352   348   450   447   446
# 1           Birds      235   321   326   331   345   351   372   382   389
# 2        Reptiles       59    74    79    78    79   101   200   284   296
# 3      Amphibians       31    38    37    37   729   738   758   764   767
# 4          Fishes      134   144   143   144   160   237   400   477   494
#
#    2013  2014  2015  2016  2017 2007 2008 2009
# 0   447   477   481   464   464  349  448  449
# 1   397   419   416   448   448  356  361  362
# 2   329   356   361   421   424  139  134  150
# 3   783   789   810   852   852  737  755  754
# 4   530   587   614   660   660  254  269  298

# %%
df2 = df2.melt(var_name = "Year", value_name = "count", id_vars=["Endangered (EN)"])
df2.head()
# Out:
#   Endangered (EN)     Year count
# 0         Mammals  1996/98   315
# 1           Birds  1996/98   235
# 2        Reptiles  1996/98    59
# 3      Amphibians  1996/98    31
# 4          Fishes  1996/98   134

# %%
df2["Year"] = df2["Year"].astype(str).str.replace("/98", "")
df2.head()
# Out:
#   Endangered (EN)  Year count
# 0         Mammals  1996   315
# 1           Birds  1996   235
# 2        Reptiles  1996    59
# 3      Amphibians  1996    31
# 4          Fishes  1996   134

# %%
df2["Year"] = df2["Year"].astype(int)

# %%
df2["count"] = df2["count"].astype(str).str.replace(",", "")

# %%
df2["count"] = df2["count"].str.replace("nan", "None")

# %%
df2 = df2[df2["count"] != "None"]
df2.tail()
# Out:
#          Endangered (EN)  Year count
# 164               Fishes  2009   298
# 165              Insects  2009   151
# 166             Molluscs  2009   245
# 167  Other Invertebrates  2009   164
# 168               Plants  2009  2316

# %%
df2["count"] = df2["count"].astype(int)

# %%
df2.dtypes
# Out:
# Endangered (EN)    object
# Year                int64
# count               int64
# dtype: object

# %%
df2.sort_values(by = "Year", ascending = True, inplace = True)

# %%
df2.head()
# Out:
#   Endangered (EN)  Year  count
# 0         Mammals  1996    315
# 1           Birds  1996    235
# 2        Reptiles  1996     59
# 3      Amphibians  1996     31
# 4          Fishes  1996    134

# %%
df2.columns = ["Endangered", "Year", "count"]
df2.head()
# Out:
#    Endangered  Year  count
# 0     Mammals  1996    315
# 1       Birds  1996    235
# 2    Reptiles  1996     59
# 3  Amphibians  1996     31
# 4      Fishes  1996    134

# %%
df2.to_csv("Endangered.csv")

# %%
df3["2007"] = df3["2007 2008 2009"].str.split(" ", 4, expand=True)[0]
df3["2008"] = df3["2007 2008 2009"].str.split(" ", 4, expand=True)[1]
df3["2009"] = df3["2007 2008 2009"].str.split(" ", 4, expand=True)[2]
df3.head()
# Out:
#   Vulnerable (VU)  1996/98  2000  2002  2003  2004  2006 2007 2008 2009  2010  \
# 0         Mammals      612   610   617   609   587   583    582 505 505   493
# 1           Birds      704   680   684   681   688   674    672 671 669   678
# 2        Reptiles      153   161   159   158   161   167    204 203 226   288
# 3      Amphibians       75    83    90    90   628   631    630 675 657   654
# 4          Fishes      443   452   442   444   470   681    693 717 810  1075
#
#    2011  2012  2013  2014  2015  2016  2017 2007 2008 2009
# 0   497   497   500   509   507   526   527  582  505  505
# 1   682   727   713   741   741   787   787  672  671  669
# 2   351   367   386   397   403   421   426  204  203  226
# 3   655   657   647   650   656   670   670  630  675  657
# 4  1137  1149  1167  1192  1211  1238  1238  693  717  810

# %%
df3.drop("2007 2008 2009", 1, inplace=True)
df3.head()
# Out:
#   Vulnerable (VU)  1996/98  2000  2002  2003  2004  2006  2010  2011  2012  \
# 0         Mammals      612   610   617   609   587   583   493   497   497
# 1           Birds      704   680   684   681   688   674   678   682   727
# 2        Reptiles      153   161   159   158   161   167   288   351   367
# 3      Amphibians       75    83    90    90   628   631   654   655   657
# 4          Fishes      443   452   442   444   470   681  1075  1137  1149
#
#    2013  2014  2015  2016  2017 2007 2008 2009
# 0   500   509   507   526   527  582  505  505
# 1   713   741   741   787   787  672  671  669
# 2   386   397   403   421   426  204  203  226
# 3   647   650   656   670   670  630  675  657
# 4  1167  1192  1211  1238  1238  693  717  810

# %%
df3_long = df3.melt(var_name = "Year", value_name = "count", id_vars=["Vulnerable (VU)"])
df3_long.head()
# Out:
#   Vulnerable (VU)     Year count
# 0         Mammals  1996/98   612
# 1           Birds  1996/98   704
# 2        Reptiles  1996/98   153
# 3      Amphibians  1996/98    75
# 4          Fishes  1996/98   443

# %%
df3_long
# Out:
#          Vulnerable (VU)     Year  count
# 0                Mammals  1996/98    612
# 1                  Birds  1996/98    704
# 2               Reptiles  1996/98    153
# 3             Amphibians  1996/98     75
# 4                 Fishes  1996/98    443
# 5                Insects  1996/98    377
# 6               Molluscs  1996/98    451
# 7    Other Invertebrates  1996/98    300
# 8                 Plants  1996/98   3222
# 9       Fungi & Protists  1996/98      0
# 10               Mammals     2000    610
# 11                 Birds     2000    680
# 12              Reptiles     2000    161
# 13            Amphibians     2000     83
# 14                Fishes     2000    452
# 15               Insects     2000    392
# 16              Molluscs     2000    479
# 17   Other Invertebrates     2000    300
# 18                Plants     2000   3331
# 19      Fungi & Protists     2000      0
# 20               Mammals     2002    617
# 21                 Birds     2002    684
# ...

# %%
import re
df3_long
df3_long["Year"] = df3_long["Year"].astype(str).str.replace("/98", "")

# %%
df3_long.head()
# Out:
#   Vulnerable (VU)  Year count
# 0         Mammals  1996   612
# 1           Birds  1996   704
# 2        Reptiles  1996   153
# 3      Amphibians  1996    75
# 4          Fishes  1996   443

# %%
df3_long["Year"] = df3_long["Year"].astype(int)

# %%
df3_long["count"] = df3_long["count"].astype(str).str.replace(",", "")

# %%
df3_long["count"] = df3_long["count"].astype(int)

# %%
df3_long.sort_values(by = "Year", ascending = True, inplace = True)

# %%
df3_long.head()
# Out:
#   Vulnerable (VU)  Year  count
# 0         Mammals  1996    612
# 1           Birds  1996    704
# 2        Reptiles  1996    153
# 3      Amphibians  1996     75
# 4          Fishes  1996    443

# %%
# df3_long.plot(kind = "line", x = "Year", y = "count", group = "Vulnerable (VU)")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-7565c1066e6d> in <module>()
# ----> 1 df3_long.plot(kind = "line", x = "Year", y = "count", group = "Vulnerable (VU)")
#
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2615                           fontsize=fontsize, colormap=colormap, table=table,
#    2616                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2617                           sort_columns=sort_columns, **kwds)
#    2618     __call__.__doc__ = plot_frame.__doc__
#    2619
#
# ...

# %%
df3_long.columns = ["Vulnerable", "Year", "count"]

# %%
df3_long.head()
# Out:
#    Vulnerable  Year  count
# 0     Mammals  1996    612
# 1       Birds  1996    704
# 2    Reptiles  1996    153
# 3  Amphibians  1996     75
# 4      Fishes  1996    443

# %%
df3_long.to_csv("Vulnerable_1.csv")

# %%
df3_long["Vulnerable"].value_counts()
# Out:
# Plants                 17
# Molluscs               17
# Amphibians             17
# Fungi & Protists       17
# Birds                  17
# Mammals                17
# Fishes                 17
# Insects                17
# Reptiles               17
# Other Invertebrates    17
# Name: Vulnerable, dtype: int64

# %%
extinct = pd.read_csv("tabula-extinct species - tabula-extinct species.csv")
extinct.head()
# Out:
#                                  Scientific name Common name  \
# 0                            Bos sauveli Kouprey         NaN
# 1        Crateromys australis Dinagat Crateromys         NaN
# 2      Crocidura trichura Christmas Island Shrew         NaN
# 3  Cryptochloris wintoni De Winton's Golden Mole         NaN
# 4       Dendrolagus mayri Wondiwoi Tree-kangaroo         NaN
#
#   IUCN Red\nList (2017-1)\nCategory  Year of\nAssessment  \
# 0                       CR(PE) 2008                  NaN
# 1                       CR(PE) 2008                  NaN
# 2                       CR(PE) 2008                  NaN
# 3                       CR(PE) 2008                  NaN
# 4                       CR(PE) 2008                  NaN
#
#   Date last recorded in\nthe wild     Type
# 0                         1969/70  MAMMALS
# 1                            1975  MAMMALS
# 2                            1985  MAMMALS
# 3                            1937  MAMMALS
# ...

# %%
extinct.tail()
# Out:
#              Scientific name           Common name  \
# 656     Viburnum divaricatum                   NaN
# 657          Xylosma serrata                   NaN
# 658  Bifurcaria galapagensis  Galápagos Stringweed
# 659      Desmarestia tropica     Tropical Acidweed
# 660    Dictyota galapagensis                   NaN
#
#     IUCN Red\nList (2017-1)\nCategory  Year of\nAssessment  \
# 656                            CR(PE)               2003.0
# 657                            CR(PE)               2015.0
# 658                            CR(PE)               2007.0
# 659                            CR(PE)               2007.0
# 660                            CR(PE)               2007.0
#
#     Date last recorded in\nthe wild      Type
# 656                     Before 1844    PLANTS
# 657                            1980    PLANTS
# 658                            1983  PROTISTS
# 659                            1972  PROTISTS
# 660                            1974  PROTISTS

# %%
extinct.columns = ["Scientific name", "Common name", "Category", "Year of Assessment", "Date last recorded in the wild", "Type"]
extinct.head()
# Out:
#                                  Scientific name Common name     Category  \
# 0                            Bos sauveli Kouprey         NaN  CR(PE) 2008
# 1        Crateromys australis Dinagat Crateromys         NaN  CR(PE) 2008
# 2      Crocidura trichura Christmas Island Shrew         NaN  CR(PE) 2008
# 3  Cryptochloris wintoni De Winton's Golden Mole         NaN  CR(PE) 2008
# 4       Dendrolagus mayri Wondiwoi Tree-kangaroo         NaN  CR(PE) 2008
#
#    Year of Assessment Date last recorded in the wild     Type
# 0                 NaN                        1969/70  MAMMALS
# 1                 NaN                           1975  MAMMALS
# 2                 NaN                           1985  MAMMALS
# 3                 NaN                           1937  MAMMALS
# 4                 NaN                           1928  MAMMALS

# %%
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/core/ops.py:798: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-92ca8c6e756a> in <module>()
# ----> 1 extinct.loc[extinct["Year of Assessment"] == "NaN"] = 0
#
# /usr/local/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     859
#     860             with np.errstate(all='ignore'):
# --> 861                 res = na_op(values, other)
#     862             if is_scalar(res):
#     863                 raise TypeError('Could not compare %s type with Series' %
#
# /usr/local/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     798                     result = getattr(x, name)(y)
# ...

# %%
extinct["Year of Assessment"].fillna(0, inplace=True)

# %%
extinct.head()
# Out:
#                                  Scientific name Common name     Category  \
# 0                            Bos sauveli Kouprey         NaN  CR(PE) 2008
# 1        Crateromys australis Dinagat Crateromys         NaN  CR(PE) 2008
# 2      Crocidura trichura Christmas Island Shrew         NaN  CR(PE) 2008
# 3  Cryptochloris wintoni De Winton's Golden Mole         NaN  CR(PE) 2008
# 4       Dendrolagus mayri Wondiwoi Tree-kangaroo         NaN  CR(PE) 2008
#
#    Year of Assessment Date last recorded in the wild     Type
# 0                 0.0                        1969/70  MAMMALS
# 1                 0.0                           1975  MAMMALS
# 2                 0.0                           1985  MAMMALS
# 3                 0.0                           1937  MAMMALS
# 4                 0.0                           1928  MAMMALS

# %%
extinct["new"] = extinct["Category"].str.split(" ", 1, expand = True)[1]
extinct.head()
# Out:
#                                  Scientific name Common name     Category  \
# 0                            Bos sauveli Kouprey         NaN  CR(PE) 2008
# 1        Crateromys australis Dinagat Crateromys         NaN  CR(PE) 2008
# 2      Crocidura trichura Christmas Island Shrew         NaN  CR(PE) 2008
# 3  Cryptochloris wintoni De Winton's Golden Mole         NaN  CR(PE) 2008
# 4       Dendrolagus mayri Wondiwoi Tree-kangaroo         NaN  CR(PE) 2008
#
#    Year of Assessment Date last recorded in the wild     Type   new
# 0                 0.0                        1969/70  MAMMALS  2008
# 1                 0.0                           1975  MAMMALS  2008
# 2                 0.0                           1985  MAMMALS  2008
# 3                 0.0                           1937  MAMMALS  2008
# 4                 0.0                           1928  MAMMALS  2008

# %%
# extinct["Year of Assessment"].where(extinct[["Year of Assessment"]] == 0, extinct["new"].values)
pd.set_option("display.max_rows",201)
extinct
# Out:
#                                        Scientific name  \
# 0                                  Bos sauveli Kouprey
# 1              Crateromys australis Dinagat Crateromys
# 2            Crocidura trichura Christmas Island Shrew
# 3        Cryptochloris wintoni De Winton's Golden Mole
# 4             Dendrolagus mayri Wondiwoi Tree-kangaroo
# 5          Dipodomys gravipes San Quintin Kangaroo Rat
# 6                             Lipotes vexillifer Baiji
# 7             Melanomys zunigae Zuniga's Dark Rice Rat
# 8                       Mesocapromys nanus Dwarf Hutia
# 9        Mesocapromys sanfelipensis Little Earth Hutia
# 10       Monodelphis unistriata Single-striped Opossum
# 11              Murina tenebrosa Gloomy Tube-nosed Bat
# 12   Mystacina robusta New Zealand Greater Short-ta...
# 13       Nilopegamys plumbeus Ethiopian Amphibious Rat
# 14       Nyctophilus howensis Lord Howe Long-eared Bat
# 15               Peromyscus guardia Angel Island Mouse
# ...

# %%
extinct.loc[0:58,"Year of Assessment"] = extinct.loc[0:58, "new"]

# %%
extinct.drop(extinct.columns[[6, 7]], axis = 1, inplace = True)

extinct.head()
# Out:
#                                  Scientific name Common name     Category  \
# 0                            Bos sauveli Kouprey         NaN  CR(PE) 2008
# 1        Crateromys australis Dinagat Crateromys         NaN  CR(PE) 2008
# 2      Crocidura trichura Christmas Island Shrew         NaN  CR(PE) 2008
# 3  Cryptochloris wintoni De Winton's Golden Mole         NaN  CR(PE) 2008
# 4       Dendrolagus mayri Wondiwoi Tree-kangaroo         NaN  CR(PE) 2008
#
#   Year of Assessment Date last recorded in the wild     Type
# 0               2008                        1969/70  MAMMALS
# 1               2008                           1975  MAMMALS
# 2               2008                           1985  MAMMALS
# 3               2008                           1937  MAMMALS
# 4               2008                           1928  MAMMALS

# %%
extinct["Category"] = extinct["Category"].str.split(" ", 1, expand = True)[0]
extinct.head()
# Out:
#                                  Scientific name Common name Category  \
# 0                            Bos sauveli Kouprey         NaN   CR(PE)
# 1        Crateromys australis Dinagat Crateromys         NaN   CR(PE)
# 2      Crocidura trichura Christmas Island Shrew         NaN   CR(PE)
# 3  Cryptochloris wintoni De Winton's Golden Mole         NaN   CR(PE)
# 4       Dendrolagus mayri Wondiwoi Tree-kangaroo         NaN   CR(PE)
#
#   Year of Assessment Date last recorded in the wild     Type
# 0               2008                        1969/70  MAMMALS
# 1               2008                           1975  MAMMALS
# 2               2008                           1985  MAMMALS
# 3               2008                           1937  MAMMALS
# 4               2008                           1928  MAMMALS

# %%
extinct["Type"].value_counts()
# Out:
# PLANTS                   151
# AMPHIBIANS               113
# MOLLUSCS (Gastropods)    113
# FISHES                    88
# INSECTS                   50
# REPTILES                  38
# MAMMALS                   28
# BIRDS                     22
# CRUSTACEANS               17
# SPIDERS                   16
# MOLLUSCS (Bivalves)       12
# MILLIPEDES                 3
# PROTISTS                   3
# WINGLESS ARTHOPODS         2
# CORALS                     2
# CENTIPEDES                 2
# WORMS                      1
# Name: Type, dtype: int64

# %%
extinct["Date last recorded in the wild"] = extinct["Date last recorded in the wild"].replace({"?": None})

# %%
extinct
# Out:
#                                        Scientific name  \
# 0                                  Bos sauveli Kouprey
# 1              Crateromys australis Dinagat Crateromys
# 2            Crocidura trichura Christmas Island Shrew
# 3        Cryptochloris wintoni De Winton's Golden Mole
# 4             Dendrolagus mayri Wondiwoi Tree-kangaroo
# 5          Dipodomys gravipes San Quintin Kangaroo Rat
# 6                             Lipotes vexillifer Baiji
# 7             Melanomys zunigae Zuniga's Dark Rice Rat
# 8                       Mesocapromys nanus Dwarf Hutia
# 9        Mesocapromys sanfelipensis Little Earth Hutia
# 10       Monodelphis unistriata Single-striped Opossum
# 11              Murina tenebrosa Gloomy Tube-nosed Bat
# 12   Mystacina robusta New Zealand Greater Short-ta...
# 13       Nilopegamys plumbeus Ethiopian Amphibious Rat
# 14       Nyctophilus howensis Lord Howe Long-eared Bat
# 15               Peromyscus guardia Angel Island Mouse
# ...

# %%
extinct.dtypes
# Out:
# Scientific name                   object
# Common name                       object
# Category                          object
# Year of Assessment                object
# Date last recorded in the wild    object
# Type                              object
# dtype: object

# %%
extinct["Year of Assessment"] = extinct["Year of Assessment"].astype(int)

# %%
extinct["Year of Assessment"].value_counts().reset_index(name='count').sort_values(['index'], ascending=True).plot(x = "index", y = "count")

# %%
extinct.head()
# Out:
#                                  Scientific name Common name Category  \
# 0                            Bos sauveli Kouprey         NaN   CR(PE)
# 1        Crateromys australis Dinagat Crateromys         NaN   CR(PE)
# 2      Crocidura trichura Christmas Island Shrew         NaN   CR(PE)
# 3  Cryptochloris wintoni De Winton's Golden Mole         NaN   CR(PE)
# 4       Dendrolagus mayri Wondiwoi Tree-kangaroo         NaN   CR(PE)
#
#    Year of Assessment Date last recorded in the wild     Type
# 0                2008                        1969/70  MAMMALS
# 1                2008                           1975  MAMMALS
# 2                2008                           1985  MAMMALS
# 3                2008                           1937  MAMMALS
# 4                2008                           1928  MAMMALS

# %%
import re
extinct["Date last recorded in the wild"] = extinct["Date last recorded in the wild"].str.replace(r"/.*", "")
extinct.head()
# Out:
#                                  Scientific name Common name Category  \
# 0                            Bos sauveli Kouprey         NaN   CR(PE)
# 1        Crateromys australis Dinagat Crateromys         NaN   CR(PE)
# 2      Crocidura trichura Christmas Island Shrew         NaN   CR(PE)
# 3  Cryptochloris wintoni De Winton's Golden Mole         NaN   CR(PE)
# 4       Dendrolagus mayri Wondiwoi Tree-kangaroo         NaN   CR(PE)
#
#    Year of Assessment Date last recorded in the wild     Type
# 0                2008                           1969  MAMMALS
# 1                2008                           1975  MAMMALS
# 2                2008                           1985  MAMMALS
# 3                2008                           1937  MAMMALS
# 4                2008                           1928  MAMMALS

# %%
extinct["Date last recorded in the wild"] = extinct["Date last recorded in the wild"].str.replace(r"24 December", "")

# %%
extinct["Date last recorded in the wild"] = extinct["Date last recorded in the wild"].str.replace("\D.* \d.*", "None")

# %%
extinct["Date last recorded in the wild"] = extinct["Date last recorded in the wild"].str.replace("\d.* \D.*", "None")

# %%
extinct["Date last recorded in the wild"] = extinct["Date last recorded in the wild"].str.replace("\d.*-\d.*", "None")

# %%
extinct
# Out:
#                                        Scientific name  \
# 0                                  Bos sauveli Kouprey
# 1              Crateromys australis Dinagat Crateromys
# 2            Crocidura trichura Christmas Island Shrew
# 3        Cryptochloris wintoni De Winton's Golden Mole
# 4             Dendrolagus mayri Wondiwoi Tree-kangaroo
# 5          Dipodomys gravipes San Quintin Kangaroo Rat
# 6                             Lipotes vexillifer Baiji
# 7             Melanomys zunigae Zuniga's Dark Rice Rat
# 8                       Mesocapromys nanus Dwarf Hutia
# 9        Mesocapromys sanfelipensis Little Earth Hutia
# 10       Monodelphis unistriata Single-striped Opossum
# 11              Murina tenebrosa Gloomy Tube-nosed Bat
# 12   Mystacina robusta New Zealand Greater Short-ta...
# 13       Nilopegamys plumbeus Ethiopian Amphibious Rat
# 14       Nyctophilus howensis Lord Howe Long-eared Bat
# 15               Peromyscus guardia Angel Island Mouse
# ...

# %%
extinct["Date last recorded in the wild"] = extinct["Date last recorded in the wild"].str.replace("\d.*s", "None")

# %%
extinct["Date last recorded in the wild"] = extinct["Date last recorded in the wild"].str.replace("19None", "None")

# %%
extinct["Date last recorded in the wild"] = extinct["Date last recorded in the wild"].str.replace("1976None", "None")
extinct.head()
# Out:
#                                  Scientific name Common name Category  \
# 0                            Bos sauveli Kouprey         NaN   CR(PE)
# 1        Crateromys australis Dinagat Crateromys         NaN   CR(PE)
# 2      Crocidura trichura Christmas Island Shrew         NaN   CR(PE)
# 3  Cryptochloris wintoni De Winton's Golden Mole         NaN   CR(PE)
# 4       Dendrolagus mayri Wondiwoi Tree-kangaroo         NaN   CR(PE)
#
#    Year of Assessment Date last recorded in the wild     Type
# 0                2008                           1969  MAMMALS
# 1                2008                           1975  MAMMALS
# 2                2008                           1985  MAMMALS
# 3                2008                           1937  MAMMALS
# 4                2008                           1928  MAMMALS

# %%
extinct["Date last recorded in the wild"] = extinct["Date last recorded in the wild"].replace({"None": None})

# %%
extinct.dtypes
# Out:
# Scientific name                   object
# Common name                       object
# Category                          object
# Year of Assessment                 int64
# Date last recorded in the wild    object
# Type                              object
# dtype: object

# %%
#this didn't work. Not sure why
extinct_no_NaN = extinct[extinct["Date last recorded in the wild"] != None]

# %%
extinct_no_NaN.loc[extinct_no_NaN["Date last recorded in the wild"].isnull(), "Date last recorded in the wild"] = 0

# %%
extinct_no_NaN = extinct_no_NaN[extinct_no_NaN["Date last recorded in the wild"] != 0]
extinct_no_NaN.head()
# Out:
#                                  Scientific name Common name Category  \
# 0                            Bos sauveli Kouprey         NaN   CR(PE)
# 1        Crateromys australis Dinagat Crateromys         NaN   CR(PE)
# 2      Crocidura trichura Christmas Island Shrew         NaN   CR(PE)
# 3  Cryptochloris wintoni De Winton's Golden Mole         NaN   CR(PE)
# 4       Dendrolagus mayri Wondiwoi Tree-kangaroo         NaN   CR(PE)
#
#    Year of Assessment Date last recorded in the wild     Type
# 0                2008                           1969  MAMMALS
# 1                2008                           1975  MAMMALS
# 2                2008                           1985  MAMMALS
# 3                2008                           1937  MAMMALS
# 4                2008                           1928  MAMMALS

# %%
extinct_no_NaN["Date last recorded in the wild"] = extinct_no_NaN["Date last recorded in the wild"].astype(str)

# %%
extinct_no_NaN["Date last recorded in the wild"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-191-60c35c2db057> in <module>()
# ----> 1 extinct_no_NaN["Date last recorded in the wild"].astype(int)
#
# /usr/local/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    3408         # else, only a single dtype is given
#    3409         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 3410                                      **kwargs)
#    3411         return self._constructor(new_data).__finalize__(self)
#    3412
#
# ...

# %%
extinct_no_NaN["test"] = extinct_no_NaN["Date last recorded in the wild"] == "None"

# %%
extinct_no_NaN["test"].value_counts()
# Out:
# False    446
# True       1
# Name: test, dtype: int64

# %%
extinct_no_NaN = extinct_no_NaN[extinct_no_NaN["Date last recorded in the wild"] != "None"]

# %%
extinct_no_NaN["test"].value_counts()
# Out:
# False    446
# Name: test, dtype: int64

# %%
extinct_no_NaN["Date last recorded in the wild"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-196-60c35c2db057> in <module>()
# ----> 1 extinct_no_NaN["Date last recorded in the wild"].astype(int)
#
# /usr/local/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    3408         # else, only a single dtype is given
#    3409         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 3410                                      **kwargs)
#    3411         return self._constructor(new_data).__finalize__(self)
#    3412
#
# ...

# %%
extinct_no_NaN = extinct_no_NaN[extinct_no_NaN["Date last recorded in the wild"] != "mid-None"]

# %%
extinct_no_NaN["Date last recorded in the wild"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-198-60c35c2db057> in <module>()
# ----> 1 extinct_no_NaN["Date last recorded in the wild"].astype(int)
#
# /usr/local/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    3408         # else, only a single dtype is given
#    3409         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 3410                                      **kwargs)
#    3411         return self._constructor(new_data).__finalize__(self)
#    3412
#
# ...

# %%
extinct_no_NaN = extinct_no_NaN[extinct_no_NaN["Date last recorded in the wild"] != "9None"]

# %%
extinct_no_NaN["Date last recorded in the wild"] = extinct_no_NaN["Date last recorded in the wild"].astype(int)

# %%
# extinct_no_NaN["Date last recorded in the wild"]
extinct_no_NaN["Date last recorded in the wild"].value_counts().reset_index(name='count').sort_values(['index'], ascending=True).plot(x = "index", y = "count")
