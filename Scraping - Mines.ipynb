# %% [markdown]
# # Mine Safety
#
# We're interested in [US mine safety](https://arlweb.msha.gov/drs/drshome.htm#MID), thank goodness we can search for these things.

# %% [markdown]
# ## Preparation: Knowing your tags
#
# These questions are the same for every data set, and might not work exactly for yours.
#
# **Search for every operator with 'dirt' in their name, including abandoned mines.**

# %% [markdown]
# ### What is the tag and class name for every row of data?

# %%
## tbody

# %% [markdown]
# ### What is the tag and class name for every mine operator's name?

# %%
## the third td
# Out:
# [<td width="30%"><a href="/drs/drshome.htm"><img alt="Mine Data Retrieval System" border="0" height="75" src="/drs/images/drslogo.png" width="300"/></a></td>,
#  <td width="30%"> </td>]

# %% [markdown]
# ### What is the tag and class name for every mine's name?

# %%
# the fourth td

# %% [markdown]
# ### What is the tag and class name for every mine operator's name?

# %%
## the third td

# %% [markdown]
# ### What is the tag and class name for every mine operator's name?

# %%
## the third td

# %% [markdown]
# ## Being lazy
#
# If you only needed these results, what would you do instead of scraping them?

# %%
## Copy paste into excel

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# Use `requests`, not `urllib`.

# %%
import requests as rq
from bs4 import BeautifulSoup

# %% [markdown]
# ## Try to scrape the page
#
# To test if you requested the page correctly, save the BeautifulSoup document as `doc` and run the code `doc.find_all('tr')[-1].text` to get the text of the last `<tr>` element.
#
# - If the result starts with **Total Number of Mines Found**, you were successful.

# %%
data = {
"OperSearch": "dirt",
"MineName": "",
"StateSearch": "None", 
"CM": "All",
"x": "20",
"y": "14",
"MC": "Opersearch"
}

# %%
url = "https://arlweb.msha.gov/drs/ASP/OprNameStatesearch.asp"
response = rq.post(url, data=data)
doc = BeautifulSoup(response.text, "html.parser")

# %%
doc.find_all('tr')[-1].text
# Out:
# '\nTotal Number of Mines Found:\xa0\xa0129'

# %% [markdown]
# ## Actually scraping

# %% [markdown]
# ### Hopefully you know that each `tr` is supposed to be your data. What is the index of the first row element that is actually a result?
#
# `.text` will help you here.

# %%
doc.find_all("tr")[7].text
# Out:
# '\n\n\n3503598\n\nOR\xa0\n Newberg Rock & Dirt \xa0\nNewberg Rock & Dirt\nSurface             \nM\xa0\nActive\xa0 \nCrushed, Broken Stone NEC\xa0 \n'

# %% [markdown]
# ### Loop through each operator result, printing its name
#
# Use LIST SLICING to skip the non-data row(s).

# %%
for i in doc.find_all("tr")[7:-1]:
    operature_name = i.find_all("font")[2]
    for n in operature_name:
        print(n)
# Out:
#  DNT
#  Newberg Rock & Dirt
#  /DNT
#
#  DNT
# Allied Dirt Moving Company
#  /DNT
#
#  DNT
# AM Dirtworks & Aggregate Sales
#  /DNT
#
#  DNT
# Atlas-Dirty Devil Mining
#  /DNT
#
#  DNT
# Atlas-Dirty Devil Mining
#  /DNT
#
#  DNT
# Babe's Dirt Work
#  /DNT
#
#  DNT
# Bar-Lin Dirt Company
#  /DNT
#
#  DNT
# Barber'S Dirt Pit
#  /DNT
#
#  DNT
# Bender Sand & Dirt
#  /DNT
#
#  DNT
# BERT'S DIRT
#  /DNT
#
#  DNT
# Big D Dirt Service Inc
#  /DNT
#
#  DNT
# Big Red Dirt Farm LLC
#  /DNT
#
#  DNT
# Big River Dirt Pit
#  /DNT
#
#  DNT
# Bob Harris Dirt Contracting
#  /DNT
#
#  DNT
# Bohannon Sand & Dirt
#  /DNT
#
#  DNT
# Bratcher'S Sand & Dirt
#  /DNT
#
#  DNT
# Brewer Dirt Works
#  /DNT
#
#  DNT
# Buck'S Dirt Pit
#  /DNT
#
#  DNT
# C & G Dirt Hauling
#  /DNT
#
#  DNT
# C N C Dirt Movers, Inc.
#  /DNT
#
#  DNT
# Cambridge Dirt Sand and Gravel LLC
#  /DNT
#
#  DNT
# Central Iowa Dirt & Demo LLC
#  /DNT
#
#  DNT
# Crowes Trucking & Dirt Pit Services
#  /DNT
#
#  DNT
# D & H Dirt
#  /DNT
#
#  DNT
# Diez Dirt & Sand Hauling Inc
#  /DNT
#
#  DNT
# Dirt Cheap
#  /DNT
#
#  DNT
# Dirt Company
#  /DNT
#
#  DNT
# Dirt Company
#  /DNT
#
#  DNT
# Dirt Company
#  /DNT
#
#  DNT
# Dirt Con
#  /DNT
#
#  DNT
# Dirt Diggers Inc
#  /DNT
#
#  DNT
# Dirt Doctor Inc
#  /DNT
#
#  DNT
# Dirt Inc
#  /DNT
#
#  DNT
# Dirt Pit
#  /DNT
#
#  DNT
# Dirt Works
#  /DNT
#
#  DNT
# Dirtco Inc
#  /DNT
#
#  DNT
# Dirtman Trucking
#  /DNT
#
#  DNT
# DIRTWORKS, INC.
#  /DNT
#
#  DNT
# Dirtworks, Inc.
#  /DNT
#
#  DNT
# Dirty Coal
#  /DNT
#
#  DNT
# Dorchester Dirt Company Inc
#  /DNT
#
#  DNT
# Douglas Dirt Sand & Gravel Company
#  /DNT
#
#  DNT
# Ell Dirt Works LLC.
#  /DNT
#
#  DNT
# Floyd Smith Dirt Pit
#  /DNT
#
#  DNT
# Gary Kelm Dirt Service
#  /DNT
#
#  DNT
# Gerald Fenger/Rock & Dirt Const
#  /DNT
#
#  DNT
# Gerald Illies Gravel & Dirt Company
#  /DNT
#
#  DNT
# Guidry Sand & Dirt Pit Inc
#  /DNT
#
#  DNT
# Harris Dirt Company Inc
#  /DNT
#
#  DNT
# Hatchet Creek Rock & Dirt LLC
#  /DNT
#
#  DNT
# Holley Dirt Company, Inc
#  /DNT
#
#  DNT
# Iske Dirt Sand & Gravel
#  /DNT
#
#  DNT
# J M Lynn Dirtwork
#  /DNT
#
#  DNT
# Jake Diel Dirt & Paving Inc
#  /DNT
#
#  DNT
# Jake Diel Dirt & Paving Inc
#  /DNT
#
#  DNT
# Jake Diel Dirt & Paving Inc
#  /DNT
#
#  DNT
# Jake Diel Dirt & Paving Inc
#  /DNT
#
#  DNT
# Jake Diel Dirt & Paving Inc
#  /DNT
#
#  DNT
# Jake Diel Dirt & Paving Inc
#  /DNT
#
#  DNT
# Jake Diel Dirt & Paving Inc
#  /DNT
#
#  DNT
# Jake Diel Dirt & Paving Inc
#  /DNT
#
#  DNT
# Jarratt Dirt Work and Paving, Inc.
#  /DNT
#
#  DNT
# JBS DIRT, INC.
#  /DNT
#
#  DNT
# Jones Bros Dirt & Paving Contractors Inc
#  /DNT
#
#  DNT
# Krueger Brothers Gravel & Dirt
#  /DNT
#
#  DNT
# Krueger Dirt Werx, Inc.
#  /DNT
#
#  DNT
# L I P Dirt & Trucking
#  /DNT
#
#  DNT
# Lee'S Dirt Pit Inc
#  /DNT
#
#  DNT
# Little-G-Dirt Pit
#  /DNT
#
#  DNT
# Lone Star Dirt & Paving
#  /DNT
#
#  DNT
# Loyd'S Dirt & Gravel
#  /DNT
#
#  DNT
# M R Dirt
#  /DNT
#
#  DNT
# M.C. Dirt LLC
#  /DNT
#
#  DNT
# M.R. Dirt Inc.
#  /DNT
#
#  DNT
# Maurice Dirt & Sand
#  /DNT
#
#  DNT
# Mc Dirt Industries Inc
#  /DNT
#
#  DNT
# Mike Duhon Dirt Pit
#  /DNT
#
#  DNT
# Mike Duhon Dirt Pit
#  /DNT
#
#  DNT
# Mike Duhon Dirt Pit
#  /DNT
#
#  DNT
# Moss Dirt Company
#  /DNT
#
#  DNT
# Moss Dirt Company
#  /DNT
#
#  DNT
# Muckler Fill Dirt & Top Soil
#  /DNT
#
#  DNT
# Nelson & Sons Dirt Haulers Inc
#  /DNT
#
#  DNT
# Nelson'S Dirt Pit
#  /DNT
#
#  DNT
# Nicholson Dirt Contracting
#  /DNT
#
#  DNT
# Nitty Gritty Dirt LLC
#  /DNT
#
#  DNT
# Northest Louisiana Dirt Contractors
#  /DNT
#
#  DNT
# Orvil Carter Dirt Contractor Inc
#  /DNT
#
#  DNT
# Orvil Carter Dirt Contractor Inc
#  /DNT
#
#  DNT
# P B Dirt Movers Inc
#  /DNT
#
#  DNT
# P B Dirt Movers Inc
#  /DNT
#
#  DNT
# P B Dirt Movers Inc
#  /DNT
#
#  DNT
# P B Dirt Movers Inc
#  /DNT
#
#  DNT
# P B Dirt Movers Inc
#  /DNT
#
#  DNT
# P B Dirt Movers Inc.
#  /DNT
#
#  DNT
# P B Dirt Movers, Inc
#  /DNT
#
#  DNT
# P.B. Dirtmovers
#  /DNT
#
#  DNT
# PAPA'S DIRT WORKES
#  /DNT
#
#  DNT
# Paydirt Exc Inc
#  /DNT
#
#  DNT
# PB Dirt Movers
#  /DNT
#
#  DNT
# PB Dirt Movers Inc.
#  /DNT
#
#  DNT
# PB Dirt Movers, Inc
#  /DNT
#
#  DNT
# Peveto Dirt Pit
#  /DNT
#
#  DNT
# Phil-Dirt Industries, Inc
#  /DNT
#
#  DNT
# Prescott Dirt, LLC
#  /DNT
#
#  DNT
# R & R Dirtworks
#  /DNT
#
#  DNT
# R D Blankenship Dirt Work LLC
#  /DNT
#
#  DNT
# Reeves Dirt Pit Inc
#  /DNT
#
#  DNT
# River Bottom Dirt
#  /DNT
#
#  DNT
# Roe'S Dirt Pit
#  /DNT
#
#  DNT
# Russell Trest-Dirt Contractor
#  /DNT
#
#  DNT
# S J Stahr Dirt Movers Inc
#  /DNT
#
#  DNT
# Sand and Dirt, Inc.
#  /DNT
#
#  DNT
# Sierra Rock & Dirt, Inc.
#  /DNT
#
#  DNT
# Simpson Dirtworx llc
#  /DNT
#
#  DNT
# SIMPSON DIRTWORX LLC
#  /DNT
#
#  DNT
# SIMPSON DIRTWORX LLC
#  /DNT
#
#  DNT
# Slay'S Dirt Hauling
#  /DNT
#
#  DNT
# Southside Dirt Company
#  /DNT
#
#  DNT
# Spry's Dirt & Gravel, Inc.
#  /DNT
#
#  DNT
# Stewart Dirt Pit
#  /DNT
#
#  DNT
# Stewart Dirt Work, Inc.
#  /DNT
#
#  DNT
# Sweat'S Dirt Hauling Inc
#  /DNT
#
#  DNT
# Toler Roe Dirt Pit
#  /DNT
#
#  DNT
# Tres Palacios Dirt, Sand & Gravel
#  /DNT
#
#  DNT
# Vogt Dirt Service
#  /DNT
#
#  DNT
# Watson Dirt Sand & Gravel Pit Inc
#  /DNT
#
#  DNT
# Y B Dirt & Loam
#  /DNT
#
#  DNT
# Yarbrough Dirt Pit Inc
#  /DNT

# %% [markdown]
# ### Loop through each operator result, printing its ID
#
# There should be ONE code per row, and NO empty rows between them.

# %%
for i in doc.find_all("tr")[7:-1]:
    ID_name = i.find_all("font")[0]
    for n in ID_name:
        print(n)
# Out:
# 3503598
# 0502030
# 4801789
# 4201449
# 4201450
# 1002257
# 1601167
# 4103265
# 1401575
# 1700776
# 1601251
# 0301963
# 1601082
# 3401751
# 1600916
# 3401211
# 0301267
# 1600956
# 2200033
# 0504953
# 3401929
# 1302445
# 1601106
# 3400915
# 1600983
# 4503200
# 3401266
# 3401468
# 5001797
# 4608254
# 1510279
# 2103723
# 0100776
# 4104016
# 4104757
# 0301729
# 0404851
# 2200734
# 5002028
# 1513393
# 3800602
# 3101630
# 3200860
# 3401762
# 2103517
# 2402626
# 2103181
# 1601124
# 1601150
# 4703427
# 0801306
# 2501216
# 3200965
# 2901371
# 2901544
# 2901709
# 4102355
# 4102420
# 4102869
# 4102951
# 4102958
# 4104876
# 3003502
# 4103258
# 3901432
# 2103556
# 1601250
# 1600908
# 1600953
# 4104185
# 2901536
# 3609624
# 3800709
# 3609931
# 1601257
# 0801275
# 1601379
# 1601380
# 1601381
# 1601134
# 1601165
# 3901042
# 1601194
# 4104054
# 4801674
# 2402474
# 1600920
# 4102955
# 4103107
# 1512530
# 1515619
# 1518318
# 4405366
# 4407196
# 1519685
# 1519799
# 4407003
# 2602570
# 2402503
# 4407296
# 1519273
# 4407270
# 4102682
# 0801259
# 0203332
# 0302015
# 2901986
# 1601127
# 4105017
# 1600986
# 4103324
# 4202013
# 0801371
# 2402115
# 4300748
# 4300768
# 4300776
# 0103209
# 1601159
# 2302283
# 4102586
# 4104475
# 3800617
# 1601234
# 4104648
# 2103518
# 1601292
# 4103429
# 4103264

# %% [markdown]
# ## Saving the results
#
# ### Loop through each `tr` to create a list of dictionaries
#
# Each dictionary must contain
#
# - Operator ID
# - Operator name
# - Mine name
# - State
# - Mine type
# - Coal or metal
# - Status
# - Commodity
#
# Create a new dictionary for each row.

# %%
dirt = []
for i in doc.find_all("tr")[7:-1]:
    dictionary = {}
    ID_name = i.find_all("font")[0]
    if ID_name:
        print(ID_name.text)
        dictionary["ID"] = ID_name.text.strip()
    State = i.find_all("font")[1]
    if State:
        print(State.text)
        dictionary["State"] = State.text.strip()
    operature_name = i.find_all("font")[2]
    if operature_name:
        print(operature_name.text)
        dictionary["Operature"] = operature_name.text.strip()
    Mine_name = i.find_all("font")[3]
    if Mine_name:
        print(Mine_name.text)
        dictionary["Mine Name"] = Mine_name.text.strip()
    Type = i.find_all("font")[4]
    if Type:
        print(Type.text)
        dictionary["Type"] = Type.text.strip()
    CM = i.find_all("font")[5]
    if CM:
        print(CM.text)
        dictionary["CM"] = CM.text.strip()
    Status = i.find_all("font")[6]
    if Status:
        print(Status.text)
        dictionary["Status"] = Status.text.strip()
    Commodity = i.find_all("font")[7]
    if Commodity:
        print(Commodity.text)
        dictionary["Commodity"] = Commodity.text.strip()
    dirt.append(dictionary)
# Out:
# 3503598
# OR
#  Newberg Rock & Dirt
# Newberg Rock & Dirt
# Surface
# M
# Active
# Crushed, Broken Stone NEC
# 0502030
# CO
# Allied Dirt Moving Company
# Allied Dirt Moving Co Pit & Plant
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4801789
# ND
# AM Dirtworks & Aggregate Sales
# AM Dirtworks & Aggregate Sales
# Surface
# M
# Intermittent
# Construction Sand and Gravel
# 4201449
# UT
# Atlas-Dirty Devil Mining
# Unit Train Loading Facility
# Facility
# C
# Abandoned
# Coal (Bituminous)
# 4201450
# UT
# Atlas-Dirty Devil Mining
# Blackie Surface Mine & Prep Plant
# Surface
# C
# Abandoned
# Coal (Bituminous)
# 1002257
# ID
# Babe's Dirt Work
# Hitt Pit, Inc.
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1601167
# LA
# Bar-Lin Dirt Company
# Bar-Lin Dirt Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4103265
# TX
# Barber'S Dirt Pit
# Barber'S Dirt Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1401575
# KS
# Bender Sand & Dirt
# BENDER SAND & DIRT
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1700776
# ME
# BERT'S DIRT
# BERT'S DIRT
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1601251
# LA
# Big D Dirt Service Inc
# Dorothy V Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 0301963
# AR
# Big Red Dirt Farm LLC
# Big Red Dirt Farm
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1601082
# LA
# Big River Dirt Pit
# Big River Dirt Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 3401751
# OK
# Bob Harris Dirt Contracting
# Harris Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1600916
# LA
# Bohannon Sand & Dirt
# BOHANNON SAND & DIRT
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 3401211
# OK
# Bratcher'S Sand & Dirt
# Eubanks Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 0301267
# AR
# Brewer Dirt Works
# Brewer Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1600956
# LA
# Buck'S Dirt Pit
# Buck'S Dirt Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 2200033
# MS
# C & G Dirt Hauling
# Laurel Brick & Tile
# Surface
# M
# Abandoned
# Common Clays NEC
# 0504953
# NM
# C N C Dirt Movers, Inc.
# Foster Canyon
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 3401929
# OK
# Cambridge Dirt Sand and Gravel LLC
# Cambridge #1
# Surface
# M
# Abandoned
# Sand, Industrial NEC
# 1302445
# IA
# Central Iowa Dirt & Demo LLC
# Woolstock
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1601106
# LA
# Crowes Trucking & Dirt Pit Services
# Crowes Dirt Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 3400915
# OK
# D & H Dirt
# D & H Dirt
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1600983
# LA
# Diez Dirt & Sand Hauling Inc
# Amite Acres Dredge
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4503200
# WA
# Dirt Cheap
# Dirt Cheap
# Surface
# M
# Abandoned
# Common Clays NEC
# 3401266
# OK
# Dirt Company
# Pit #1
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 3401468
# OK
# Dirt Company
# Hicks Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 5001797
# AK
# Dirt Company
# Bush Pilot
# Surface
# M
# Intermittent
# Construction Sand and Gravel
# 4608254
# WV
# Dirt Con
# Hog Lick Quarry
# Surface
# M
# Temporarily Idled
# Crushed, Broken Limestone NEC
# 1510279
# KY
# Dirt Diggers Inc
# Debco Mine
# Surface
# C
# Abandoned
# Coal (Bituminous)
# 2103723
# MN
# Dirt Doctor Inc
# Rock Lake Plant
# Surface
# M
# Intermittent
# Construction Sand and Gravel
# 0100776
# AL
# Dirt Inc
# Harrison Pit
# Surface
# M
# Abandoned
# Common Clays NEC
# 4104016
# TX
# Dirt Pit
# THE DIRT PIT
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4104757
# TX
# Dirt Works
# Portable #1
# Surface
# M
# Intermittent
# Construction Sand and Gravel
# 0301729
# AR
# Dirtco Inc
# DIRTCO INC
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 0404851
# CA
# Dirtman Trucking
# Dirtman Sand & Gravel #2
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 2200734
# MS
# DIRTWORKS, INC.
# DIRTWORKS, INC.
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 5002028
# AK
# Dirtworks, Inc.
# Dirtworks, Inc.
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1513393
# KY
# Dirty Coal
# No 1 Surface
# Surface
# C
# Abandoned
# Coal (Bituminous)
# 3800602
# SC
# Dorchester Dirt Company Inc
# DIAMOND MINE #3
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 3101630
# NC
# Douglas Dirt Sand & Gravel Company
# Mccormick Pit & Plant
# Surface
# M
# Abandoned
# Crushed, Broken Granite
# 3200860
# ND
# Ell Dirt Works LLC.
# Portable Jaw #1
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 3401762
# OK
# Floyd Smith Dirt Pit
# Floyd Smith Dirt Pit
# Surface
# M
# Abandoned
# Dimension Stone NEC
# 2103517
# MN
# Gary Kelm Dirt Service
# Screener
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 2402626
# MT
# Gerald Fenger/Rock & Dirt Const
# Aden Ward
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 2103181
# MN
# Gerald Illies Gravel & Dirt Company
# PORTABLE CRUSHER
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1601124
# LA
# Guidry Sand & Dirt Pit Inc
# Guidry Sand & Dirt Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1601150
# LA
# Harris Dirt Company Inc
# Harris Dirt Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4703427
# WI
# Hatchet Creek Rock & Dirt LLC
# Hatchet Creek Rock & Dirt LLC
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 0801306
# FL
# Holley Dirt Company, Inc
# River Road Pit
# Surface
# M
# Active
# Sand, Common
# 2501216
# NE
# Iske Dirt Sand & Gravel
# Iske Dirt Sand & Gravel
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 3200965
# ND
# J M Lynn Dirtwork
# Johnson Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 2901371
# NM
# Jake Diel Dirt & Paving Inc
# Diel Screening Plant
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 2901544
# NM
# Jake Diel Dirt & Paving Inc
# Cortez Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 2901709
# NM
# Jake Diel Dirt & Paving Inc
# Skaggs Pit
# Surface
# M
# Abandoned
# Crushed, Broken Stone NEC
# 4102355
# TX
# Jake Diel Dirt & Paving Inc
# Jacobson Pit
# Surface
# M
# Abandoned
# Crushed, Broken Limestone NEC
# 4102420
# TX
# Jake Diel Dirt & Paving Inc
# Black Pit
# Surface
# M
# Abandoned
# Crushed, Broken Limestone NEC
# 4102869
# TX
# Jake Diel Dirt & Paving Inc
# Bailey Pit
# Surface
# M
# Abandoned
# Crushed, Broken Stone NEC
# 4102951
# TX
# Jake Diel Dirt & Paving Inc
# Toscosa Pit
# Surface
# M
# Abandoned
# Crushed, Broken Limestone NEC
# 4102958
# TX
# Jake Diel Dirt & Paving Inc
# Four Way Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4104876
# TX
# Jarratt Dirt Work and Paving, Inc.
# Portable Screening Plant #1
# Surface
# M
# Abandoned
# Crushed, Broken Stone NEC
# 3003502
# NY
# JBS DIRT, INC.
# SHAMROCK PIT
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4103258
# TX
# Jones Bros Dirt & Paving Contractors Inc
# Barstow Pit
# Surface
# M
# Abandoned
# Crushed, Broken Limestone NEC
# 3901432
# SD
# Krueger Brothers Gravel & Dirt
# PORTABLE SCREENER
# Surface
# M
# Intermittent
# Construction Sand and Gravel
# 2103556
# MN
# Krueger Dirt Werx, Inc.
# Krueger Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1601250
# LA
# L I P Dirt & Trucking
# L I P Dirt & Trucking
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1600908
# LA
# Lee'S Dirt Pit Inc
# Lee'S Dirt Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1600953
# LA
# Little-G-Dirt Pit
# Little-G-Dirt Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4104185
# TX
# Lone Star Dirt & Paving
# Lone Star Crusher
# Surface
# M
# Abandoned
# Crushed, Broken Stone NEC
# 2901536
# NM
# Loyd'S Dirt & Gravel
# LOYD'S PIT
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 3609624
# PA
# M R Dirt
# Forbes Pit
# Surface
# M
# Intermittent
# Construction Sand and Gravel
# 3800709
# SC
# M.C. Dirt LLC
# Middleton Site
# Surface
# M
# Abandoned
# Sand, Common
# 3609931
# PA
# M.R. Dirt Inc.
# Camptown Quarry
# Surface
# M
# Intermittent
# Dimension Stone NEC
# 1601257
# LA
# Maurice Dirt & Sand
# Maurice Dirt And Sand
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 0801275
# FL
# Mc Dirt Industries Inc
# BELLVIEW
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1601379
# LA
# Mike Duhon Dirt Pit
# REDS PIT
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1601380
# LA
# Mike Duhon Dirt Pit
# WAINWRIGHT PIT
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1601381
# LA
# Mike Duhon Dirt Pit
# COX PIT
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1601134
# LA
# Moss Dirt Company
# Cook Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1601165
# LA
# Moss Dirt Company
# Moss Dirt Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 3901042
# SD
# Muckler Fill Dirt & Top Soil
# Hoffman Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1601194
# LA
# Nelson & Sons Dirt Haulers Inc
# Nelson & Sons Dirt Haulers Incorporated
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4104054
# TX
# Nelson'S Dirt Pit
# NELSON'S DIRT PIT
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4801674
# WY
# Nicholson Dirt Contracting
# Eagle One
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 2402474
# MT
# Nitty Gritty Dirt LLC
# Rolling Glen Ranch Sand and Gravel
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1600920
# LA
# Northest Louisiana Dirt Contractors
# Calhoun And Mcguire Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4102955
# TX
# Orvil Carter Dirt Contractor Inc
# Ed Meek Pit
# Surface
# M
# Abandoned
# Crushed, Broken Limestone NEC
# 4103107
# TX
# Orvil Carter Dirt Contractor Inc
# Seitz Pit
# Surface
# M
# Abandoned
# Crushed, Broken Limestone NEC
# 1512530
# KY
# P B Dirt Movers Inc
# No 1 Surface
# Surface
# C
# Abandoned
# Coal (Bituminous)
# 1515619
# KY
# P B Dirt Movers Inc
# No 5 Surface
# Surface
# C
# Abandoned
# Coal (Bituminous)
# 1518318
# KY
# P B Dirt Movers Inc
# Biggs No 1
# Surface
# C
# Abandoned
# Coal (Bituminous)
# 4405366
# VA
# P B Dirt Movers Inc
# No 1 Strip
# Surface
# C
# Abandoned
# Coal (Bituminous)
# 4407196
# VA
# P B Dirt Movers Inc
# No 2
# Surface
# C
# Abandoned
# Coal (Bituminous)
# 1519685
# KY
# P B Dirt Movers Inc.
# Fedscreek Refuse Pile
# Surface
# C
# Abandoned
# Coal (Bituminous)
# 1519799
# KY
# P B Dirt Movers, Inc
# Fedscreek Surface
# Surface
# C
# Active
# Coal (Bituminous)
# 4407003
# VA
# P.B. Dirtmovers
# No 2
# Underground
# C
# Abandoned*
# Coal (Bituminous)
# 2602570
# NV
# PAPA'S DIRT WORKES
# COUNTY FAIRE TEMP GRAVEL PIT
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 2402503
# MT
# Paydirt Exc Inc
# Robison Mine
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4407296
# VA
# PB Dirt Movers
# Mine No. 6
# Underground
# C
# Temporarily Idled
# Coal (Bituminous)
# 1519273
# KY
# PB Dirt Movers Inc.
# Blair Face Up
# Surface
# C
# Abandoned
# Coal (Bituminous)
# 4407270
# VA
# PB Dirt Movers, Inc
# Surface Mine No. 1
# Surface
# C
# NonProducing
# Coal (Bituminous)
# 4102682
# TX
# Peveto Dirt Pit
# Peveto Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 0801259
# FL
# Phil-Dirt Industries, Inc
# PIT #1
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 0203332
# AZ
# Prescott Dirt, LLC
# Sandretto Drive
# Surface
# M
# Intermittent
# Construction Sand and Gravel
# 0302015
# AR
# R & R Dirtworks
# Martins Quarry
# Surface
# M
# Abandoned
# Crushed, Broken Limestone NEC
# 2901986
# NM
# R D Blankenship Dirt Work LLC
# R D BLANKENSHIP DIRT WORK
# Surface
# M
# Active
# Construction Sand and Gravel
# 1601127
# LA
# Reeves Dirt Pit Inc
# Reeves Dirt Pit Incorporated
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4105017
# TX
# River Bottom Dirt
# River Bottom Dirt
# Surface
# M
# Abandoned
# Sand, Common
# 1600986
# LA
# Roe'S Dirt Pit
# Roe'S Dirt Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4103324
# TX
# Russell Trest-Dirt Contractor
# Pine Ridge Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4202013
# UT
# S J Stahr Dirt Movers Inc
# Stahr Portable Crusher
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 0801371
# FL
# Sand and Dirt, Inc.
# CENTURY PIT
# Surface
# M
# Abandoned
# Sand, Common
# 2402115
# MT
# Sierra Rock & Dirt, Inc.
# Sierra Rock & Dirt Inc
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4300748
# VT
# Simpson Dirtworx llc
# Simpson Sand and Gravel
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4300768
# VT
# SIMPSON DIRTWORX LLC
# Pettibone Jaw Crusher
# Surface
# M
# Intermittent
# Construction Sand and Gravel
# 4300776
# VT
# SIMPSON DIRTWORX LLC
# Chieftan 1400
# Surface
# M
# Intermittent
# Construction Sand and Gravel
# 0103209
# AL
# Slay'S Dirt Hauling
# SLAY PIT
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1601159
# LA
# Southside Dirt Company
# Southside Dirt Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 2302283
# MO
# Spry's Dirt & Gravel, Inc.
# Mike's Money Pit
# Surface
# M
# Intermittent
# Construction Sand and Gravel
# 4102586
# TX
# Stewart Dirt Pit
# Stewart Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4104475
# TX
# Stewart Dirt Work, Inc.
# Stewart Dirt Work Inc - Hanna Pit
# Surface
# M
# Abandoned
# Crushed, Broken Stone NEC
# 3800617
# SC
# Sweat'S Dirt Hauling Inc
# Highway 642 Dirt Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 1601234
# LA
# Toler Roe Dirt Pit
# Toler Roe Dirt Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4104648
# TX
# Tres Palacios Dirt, Sand & Gravel
# La Calichera Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 2103518
# MN
# Vogt Dirt Service
# Crusher
# Surface
# M
# Intermittent
# Construction Sand and Gravel
# 1601292
# LA
# Watson Dirt Sand & Gravel Pit Inc
# ADDISON LEASE
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4103429
# TX
# Y B Dirt & Loam
# Y B Mine
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# 4103264
# TX
# Yarbrough Dirt Pit Inc
# Yarbrough Dirt Pit #1
# Surface
# M
# Abandoned
# Construction Sand and Gravel

# %%
dirt
# Out:
# [{'CM': 'M',
#   'Commodity': 'Crushed, Broken Stone NEC',
#   'ID': '3503598',
#   'Mine Name': 'Newberg Rock & Dirt',
#   'Operature': 'Newberg Rock & Dirt',
#   'State': 'OR',
#   'Status': 'Active',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '0502030',
#   'Mine Name': 'Allied Dirt Moving Co Pit & Plant',
#   'Operature': 'Allied Dirt Moving Company',
#   'State': 'CO',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '4801789',
#   'Mine Name': 'AM Dirtworks & Aggregate Sales',
#   'Operature': 'AM Dirtworks & Aggregate Sales',
#   'State': 'ND',
#   'Status': 'Intermittent',
#   'Type': 'Surface'},
#  {'CM': 'C',
#   'Commodity': 'Coal (Bituminous)',
#   'ID': '4201449',
#   'Mine Name': 'Unit Train Loading Facility',
#   'Operature': 'Atlas-Dirty Devil Mining',
#   'State': 'UT',
#   'Status': 'Abandoned',
#   'Type': 'Facility'},
#  {'CM': 'C',
#   'Commodity': 'Coal (Bituminous)',
#   'ID': '4201450',
#   'Mine Name': 'Blackie Surface Mine & Prep Plant',
#   'Operature': 'Atlas-Dirty Devil Mining',
#   'State': 'UT',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1002257',
#   'Mine Name': 'Hitt Pit, Inc.',
#   'Operature': "Babe's Dirt Work",
#   'State': 'ID',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1601167',
#   'Mine Name': 'Bar-Lin Dirt Pit',
#   'Operature': 'Bar-Lin Dirt Company',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '4103265',
#   'Mine Name': "Barber'S Dirt Pit",
#   'Operature': "Barber'S Dirt Pit",
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1401575',
#   'Mine Name': 'BENDER SAND & DIRT',
#   'Operature': 'Bender Sand & Dirt',
#   'State': 'KS',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1700776',
#   'Mine Name': "BERT'S DIRT",
#   'Operature': "BERT'S DIRT",
#   'State': 'ME',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1601251',
#   'Mine Name': 'Dorothy V Pit',
#   'Operature': 'Big D Dirt Service Inc',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '0301963',
#   'Mine Name': 'Big Red Dirt Farm',
#   'Operature': 'Big Red Dirt Farm LLC',
#   'State': 'AR',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1601082',
#   'Mine Name': 'Big River Dirt Pit',
#   'Operature': 'Big River Dirt Pit',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '3401751',
#   'Mine Name': 'Harris Pit',
#   'Operature': 'Bob Harris Dirt Contracting',
#   'State': 'OK',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1600916',
#   'Mine Name': 'BOHANNON SAND & DIRT',
#   'Operature': 'Bohannon Sand & Dirt',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '3401211',
#   'Mine Name': 'Eubanks Pit',
#   'Operature': "Bratcher'S Sand & Dirt",
#   'State': 'OK',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '0301267',
#   'Mine Name': 'Brewer Pit',
#   'Operature': 'Brewer Dirt Works',
#   'State': 'AR',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1600956',
#   'Mine Name': "Buck'S Dirt Pit",
#   'Operature': "Buck'S Dirt Pit",
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Common Clays NEC',
#   'ID': '2200033',
#   'Mine Name': 'Laurel Brick & Tile',
#   'Operature': 'C & G Dirt Hauling',
#   'State': 'MS',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '0504953',
#   'Mine Name': 'Foster Canyon',
#   'Operature': 'C N C Dirt Movers, Inc.',
#   'State': 'NM',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Sand, Industrial NEC',
#   'ID': '3401929',
#   'Mine Name': 'Cambridge #1',
#   'Operature': 'Cambridge Dirt Sand and Gravel LLC',
#   'State': 'OK',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1302445',
#   'Mine Name': 'Woolstock',
#   'Operature': 'Central Iowa Dirt & Demo LLC',
#   'State': 'IA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1601106',
#   'Mine Name': 'Crowes Dirt Pit',
#   'Operature': 'Crowes Trucking & Dirt Pit Services',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '3400915',
#   'Mine Name': 'D & H Dirt',
#   'Operature': 'D & H Dirt',
#   'State': 'OK',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1600983',
#   'Mine Name': 'Amite Acres Dredge',
#   'Operature': 'Diez Dirt & Sand Hauling Inc',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Common Clays NEC',
#   'ID': '4503200',
#   'Mine Name': 'Dirt Cheap',
#   'Operature': 'Dirt Cheap',
#   'State': 'WA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '3401266',
#   'Mine Name': 'Pit #1',
#   'Operature': 'Dirt Company',
#   'State': 'OK',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '3401468',
#   'Mine Name': 'Hicks Pit',
#   'Operature': 'Dirt Company',
#   'State': 'OK',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '5001797',
#   'Mine Name': 'Bush Pilot',
#   'Operature': 'Dirt Company',
#   'State': 'AK',
#   'Status': 'Intermittent',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Crushed, Broken Limestone NEC',
#   'ID': '4608254',
#   'Mine Name': 'Hog Lick Quarry',
#   'Operature': 'Dirt Con',
#   'State': 'WV',
#   'Status': 'Temporarily Idled',
#   'Type': 'Surface'},
#  {'CM': 'C',
#   'Commodity': 'Coal (Bituminous)',
#   'ID': '1510279',
#   'Mine Name': 'Debco Mine',
#   'Operature': 'Dirt Diggers Inc',
#   'State': 'KY',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '2103723',
#   'Mine Name': 'Rock Lake Plant',
#   'Operature': 'Dirt Doctor Inc',
#   'State': 'MN',
#   'Status': 'Intermittent',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Common Clays NEC',
#   'ID': '0100776',
#   'Mine Name': 'Harrison Pit',
#   'Operature': 'Dirt Inc',
#   'State': 'AL',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '4104016',
#   'Mine Name': 'THE DIRT PIT',
#   'Operature': 'Dirt Pit',
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '4104757',
#   'Mine Name': 'Portable #1',
#   'Operature': 'Dirt Works',
#   'State': 'TX',
#   'Status': 'Intermittent',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '0301729',
#   'Mine Name': 'DIRTCO INC',
#   'Operature': 'Dirtco Inc',
#   'State': 'AR',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '0404851',
#   'Mine Name': 'Dirtman Sand & Gravel #2',
#   'Operature': 'Dirtman Trucking',
#   'State': 'CA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '2200734',
#   'Mine Name': 'DIRTWORKS, INC.',
#   'Operature': 'DIRTWORKS, INC.',
#   'State': 'MS',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '5002028',
#   'Mine Name': 'Dirtworks, Inc.',
#   'Operature': 'Dirtworks, Inc.',
#   'State': 'AK',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'C',
#   'Commodity': 'Coal (Bituminous)',
#   'ID': '1513393',
#   'Mine Name': 'No 1 Surface',
#   'Operature': 'Dirty Coal',
#   'State': 'KY',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '3800602',
#   'Mine Name': 'DIAMOND MINE #3',
#   'Operature': 'Dorchester Dirt Company Inc',
#   'State': 'SC',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Crushed, Broken Granite',
#   'ID': '3101630',
#   'Mine Name': 'Mccormick Pit & Plant',
#   'Operature': 'Douglas Dirt Sand & Gravel Company',
#   'State': 'NC',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '3200860',
#   'Mine Name': 'Portable Jaw #1',
#   'Operature': 'Ell Dirt Works LLC.',
#   'State': 'ND',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Dimension Stone NEC',
#   'ID': '3401762',
#   'Mine Name': 'Floyd Smith Dirt Pit',
#   'Operature': 'Floyd Smith Dirt Pit',
#   'State': 'OK',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '2103517',
#   'Mine Name': 'Screener',
#   'Operature': 'Gary Kelm Dirt Service',
#   'State': 'MN',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '2402626',
#   'Mine Name': 'Aden Ward',
#   'Operature': 'Gerald Fenger/Rock & Dirt Const',
#   'State': 'MT',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '2103181',
#   'Mine Name': 'PORTABLE CRUSHER',
#   'Operature': 'Gerald Illies Gravel & Dirt Company',
#   'State': 'MN',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1601124',
#   'Mine Name': 'Guidry Sand & Dirt Pit',
#   'Operature': 'Guidry Sand & Dirt Pit Inc',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1601150',
#   'Mine Name': 'Harris Dirt Pit',
#   'Operature': 'Harris Dirt Company Inc',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '4703427',
#   'Mine Name': 'Hatchet Creek Rock & Dirt LLC',
#   'Operature': 'Hatchet Creek Rock & Dirt LLC',
#   'State': 'WI',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Sand, Common',
#   'ID': '0801306',
#   'Mine Name': 'River Road Pit',
#   'Operature': 'Holley Dirt Company, Inc',
#   'State': 'FL',
#   'Status': 'Active',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '2501216',
#   'Mine Name': 'Iske Dirt Sand & Gravel',
#   'Operature': 'Iske Dirt Sand & Gravel',
#   'State': 'NE',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '3200965',
#   'Mine Name': 'Johnson Pit',
#   'Operature': 'J M Lynn Dirtwork',
#   'State': 'ND',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '2901371',
#   'Mine Name': 'Diel Screening Plant',
#   'Operature': 'Jake Diel Dirt & Paving Inc',
#   'State': 'NM',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '2901544',
#   'Mine Name': 'Cortez Pit',
#   'Operature': 'Jake Diel Dirt & Paving Inc',
#   'State': 'NM',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Crushed, Broken Stone NEC',
#   'ID': '2901709',
#   'Mine Name': 'Skaggs Pit',
#   'Operature': 'Jake Diel Dirt & Paving Inc',
#   'State': 'NM',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Crushed, Broken Limestone NEC',
#   'ID': '4102355',
#   'Mine Name': 'Jacobson Pit',
#   'Operature': 'Jake Diel Dirt & Paving Inc',
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Crushed, Broken Limestone NEC',
#   'ID': '4102420',
#   'Mine Name': 'Black Pit',
#   'Operature': 'Jake Diel Dirt & Paving Inc',
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Crushed, Broken Stone NEC',
#   'ID': '4102869',
#   'Mine Name': 'Bailey Pit',
#   'Operature': 'Jake Diel Dirt & Paving Inc',
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Crushed, Broken Limestone NEC',
#   'ID': '4102951',
#   'Mine Name': 'Toscosa Pit',
#   'Operature': 'Jake Diel Dirt & Paving Inc',
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '4102958',
#   'Mine Name': 'Four Way Pit',
#   'Operature': 'Jake Diel Dirt & Paving Inc',
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Crushed, Broken Stone NEC',
#   'ID': '4104876',
#   'Mine Name': 'Portable Screening Plant #1',
#   'Operature': 'Jarratt Dirt Work and Paving, Inc.',
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '3003502',
#   'Mine Name': 'SHAMROCK PIT',
#   'Operature': 'JBS DIRT, INC.',
#   'State': 'NY',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Crushed, Broken Limestone NEC',
#   'ID': '4103258',
#   'Mine Name': 'Barstow Pit',
#   'Operature': 'Jones Bros Dirt & Paving Contractors Inc',
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '3901432',
#   'Mine Name': 'PORTABLE SCREENER',
#   'Operature': 'Krueger Brothers Gravel & Dirt',
#   'State': 'SD',
#   'Status': 'Intermittent',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '2103556',
#   'Mine Name': 'Krueger Pit',
#   'Operature': 'Krueger Dirt Werx, Inc.',
#   'State': 'MN',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1601250',
#   'Mine Name': 'L I P Dirt & Trucking',
#   'Operature': 'L I P Dirt & Trucking',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1600908',
#   'Mine Name': "Lee'S Dirt Pit",
#   'Operature': "Lee'S Dirt Pit Inc",
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1600953',
#   'Mine Name': 'Little-G-Dirt Pit',
#   'Operature': 'Little-G-Dirt Pit',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Crushed, Broken Stone NEC',
#   'ID': '4104185',
#   'Mine Name': 'Lone Star Crusher',
#   'Operature': 'Lone Star Dirt & Paving',
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '2901536',
#   'Mine Name': "LOYD'S PIT",
#   'Operature': "Loyd'S Dirt & Gravel",
#   'State': 'NM',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '3609624',
#   'Mine Name': 'Forbes Pit',
#   'Operature': 'M R Dirt',
#   'State': 'PA',
#   'Status': 'Intermittent',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Sand, Common',
#   'ID': '3800709',
#   'Mine Name': 'Middleton Site',
#   'Operature': 'M.C. Dirt LLC',
#   'State': 'SC',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Dimension Stone NEC',
#   'ID': '3609931',
#   'Mine Name': 'Camptown Quarry',
#   'Operature': 'M.R. Dirt Inc.',
#   'State': 'PA',
#   'Status': 'Intermittent',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1601257',
#   'Mine Name': 'Maurice Dirt And Sand',
#   'Operature': 'Maurice Dirt & Sand',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '0801275',
#   'Mine Name': 'BELLVIEW',
#   'Operature': 'Mc Dirt Industries Inc',
#   'State': 'FL',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1601379',
#   'Mine Name': 'REDS PIT',
#   'Operature': 'Mike Duhon Dirt Pit',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1601380',
#   'Mine Name': 'WAINWRIGHT PIT',
#   'Operature': 'Mike Duhon Dirt Pit',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1601381',
#   'Mine Name': 'COX PIT',
#   'Operature': 'Mike Duhon Dirt Pit',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1601134',
#   'Mine Name': 'Cook Pit',
#   'Operature': 'Moss Dirt Company',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1601165',
#   'Mine Name': 'Moss Dirt Pit',
#   'Operature': 'Moss Dirt Company',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '3901042',
#   'Mine Name': 'Hoffman Pit',
#   'Operature': 'Muckler Fill Dirt & Top Soil',
#   'State': 'SD',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1601194',
#   'Mine Name': 'Nelson & Sons Dirt Haulers Incorporated',
#   'Operature': 'Nelson & Sons Dirt Haulers Inc',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '4104054',
#   'Mine Name': "NELSON'S DIRT PIT",
#   'Operature': "Nelson'S Dirt Pit",
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '4801674',
#   'Mine Name': 'Eagle One',
#   'Operature': 'Nicholson Dirt Contracting',
#   'State': 'WY',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '2402474',
#   'Mine Name': 'Rolling Glen Ranch Sand and Gravel',
#   'Operature': 'Nitty Gritty Dirt LLC',
#   'State': 'MT',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1600920',
#   'Mine Name': 'Calhoun And Mcguire Pit',
#   'Operature': 'Northest Louisiana Dirt Contractors',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Crushed, Broken Limestone NEC',
#   'ID': '4102955',
#   'Mine Name': 'Ed Meek Pit',
#   'Operature': 'Orvil Carter Dirt Contractor Inc',
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Crushed, Broken Limestone NEC',
#   'ID': '4103107',
#   'Mine Name': 'Seitz Pit',
#   'Operature': 'Orvil Carter Dirt Contractor Inc',
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'C',
#   'Commodity': 'Coal (Bituminous)',
#   'ID': '1512530',
#   'Mine Name': 'No 1 Surface',
#   'Operature': 'P B Dirt Movers Inc',
#   'State': 'KY',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'C',
#   'Commodity': 'Coal (Bituminous)',
#   'ID': '1515619',
#   'Mine Name': 'No 5 Surface',
#   'Operature': 'P B Dirt Movers Inc',
#   'State': 'KY',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'C',
#   'Commodity': 'Coal (Bituminous)',
#   'ID': '1518318',
#   'Mine Name': 'Biggs No 1',
#   'Operature': 'P B Dirt Movers Inc',
#   'State': 'KY',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'C',
#   'Commodity': 'Coal (Bituminous)',
#   'ID': '4405366',
#   'Mine Name': 'No 1 Strip',
#   'Operature': 'P B Dirt Movers Inc',
#   'State': 'VA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'C',
#   'Commodity': 'Coal (Bituminous)',
#   'ID': '4407196',
#   'Mine Name': 'No 2',
#   'Operature': 'P B Dirt Movers Inc',
#   'State': 'VA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'C',
#   'Commodity': 'Coal (Bituminous)',
#   'ID': '1519685',
#   'Mine Name': 'Fedscreek Refuse Pile',
#   'Operature': 'P B Dirt Movers Inc.',
#   'State': 'KY',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'C',
#   'Commodity': 'Coal (Bituminous)',
#   'ID': '1519799',
#   'Mine Name': 'Fedscreek Surface',
#   'Operature': 'P B Dirt Movers, Inc',
#   'State': 'KY',
#   'Status': 'Active',
#   'Type': 'Surface'},
#  {'CM': 'C',
#   'Commodity': 'Coal (Bituminous)',
#   'ID': '4407003',
#   'Mine Name': 'No 2',
#   'Operature': 'P.B. Dirtmovers',
#   'State': 'VA',
#   'Status': 'Abandoned*',
#   'Type': 'Underground'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '2602570',
#   'Mine Name': 'COUNTY FAIRE TEMP GRAVEL PIT',
#   'Operature': "PAPA'S DIRT WORKES",
#   'State': 'NV',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '2402503',
#   'Mine Name': 'Robison Mine',
#   'Operature': 'Paydirt Exc Inc',
#   'State': 'MT',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'C',
#   'Commodity': 'Coal (Bituminous)',
#   'ID': '4407296',
#   'Mine Name': 'Mine No. 6',
#   'Operature': 'PB Dirt Movers',
#   'State': 'VA',
#   'Status': 'Temporarily Idled',
#   'Type': 'Underground'},
#  {'CM': 'C',
#   'Commodity': 'Coal (Bituminous)',
#   'ID': '1519273',
#   'Mine Name': 'Blair Face Up',
#   'Operature': 'PB Dirt Movers Inc.',
#   'State': 'KY',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'C',
#   'Commodity': 'Coal (Bituminous)',
#   'ID': '4407270',
#   'Mine Name': 'Surface Mine No. 1',
#   'Operature': 'PB Dirt Movers, Inc',
#   'State': 'VA',
#   'Status': 'NonProducing',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '4102682',
#   'Mine Name': 'Peveto Pit',
#   'Operature': 'Peveto Dirt Pit',
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '0801259',
#   'Mine Name': 'PIT #1',
#   'Operature': 'Phil-Dirt Industries, Inc',
#   'State': 'FL',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '0203332',
#   'Mine Name': 'Sandretto Drive',
#   'Operature': 'Prescott Dirt, LLC',
#   'State': 'AZ',
#   'Status': 'Intermittent',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Crushed, Broken Limestone NEC',
#   'ID': '0302015',
#   'Mine Name': 'Martins Quarry',
#   'Operature': 'R & R Dirtworks',
#   'State': 'AR',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '2901986',
#   'Mine Name': 'R D BLANKENSHIP DIRT WORK',
#   'Operature': 'R D Blankenship Dirt Work LLC',
#   'State': 'NM',
#   'Status': 'Active',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1601127',
#   'Mine Name': 'Reeves Dirt Pit Incorporated',
#   'Operature': 'Reeves Dirt Pit Inc',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Sand, Common',
#   'ID': '4105017',
#   'Mine Name': 'River Bottom Dirt',
#   'Operature': 'River Bottom Dirt',
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1600986',
#   'Mine Name': "Roe'S Dirt Pit",
#   'Operature': "Roe'S Dirt Pit",
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '4103324',
#   'Mine Name': 'Pine Ridge Pit',
#   'Operature': 'Russell Trest-Dirt Contractor',
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '4202013',
#   'Mine Name': 'Stahr Portable Crusher',
#   'Operature': 'S J Stahr Dirt Movers Inc',
#   'State': 'UT',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Sand, Common',
#   'ID': '0801371',
#   'Mine Name': 'CENTURY PIT',
#   'Operature': 'Sand and Dirt, Inc.',
#   'State': 'FL',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '2402115',
#   'Mine Name': 'Sierra Rock & Dirt Inc',
#   'Operature': 'Sierra Rock & Dirt, Inc.',
#   'State': 'MT',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '4300748',
#   'Mine Name': 'Simpson Sand and Gravel',
#   'Operature': 'Simpson Dirtworx llc',
#   'State': 'VT',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '4300768',
#   'Mine Name': 'Pettibone Jaw Crusher',
#   'Operature': 'SIMPSON DIRTWORX LLC',
#   'State': 'VT',
#   'Status': 'Intermittent',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '4300776',
#   'Mine Name': 'Chieftan 1400',
#   'Operature': 'SIMPSON DIRTWORX LLC',
#   'State': 'VT',
#   'Status': 'Intermittent',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '0103209',
#   'Mine Name': 'SLAY PIT',
#   'Operature': "Slay'S Dirt Hauling",
#   'State': 'AL',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1601159',
#   'Mine Name': 'Southside Dirt Pit',
#   'Operature': 'Southside Dirt Company',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '2302283',
#   'Mine Name': "Mike's Money Pit",
#   'Operature': "Spry's Dirt & Gravel, Inc.",
#   'State': 'MO',
#   'Status': 'Intermittent',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '4102586',
#   'Mine Name': 'Stewart Pit',
#   'Operature': 'Stewart Dirt Pit',
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Crushed, Broken Stone NEC',
#   'ID': '4104475',
#   'Mine Name': 'Stewart Dirt Work Inc - Hanna Pit',
#   'Operature': 'Stewart Dirt Work, Inc.',
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '3800617',
#   'Mine Name': 'Highway 642 Dirt Pit',
#   'Operature': "Sweat'S Dirt Hauling Inc",
#   'State': 'SC',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1601234',
#   'Mine Name': 'Toler Roe Dirt Pit',
#   'Operature': 'Toler Roe Dirt Pit',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '4104648',
#   'Mine Name': 'La Calichera Pit',
#   'Operature': 'Tres Palacios Dirt, Sand & Gravel',
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '2103518',
#   'Mine Name': 'Crusher',
#   'Operature': 'Vogt Dirt Service',
#   'State': 'MN',
#   'Status': 'Intermittent',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '1601292',
#   'Mine Name': 'ADDISON LEASE',
#   'Operature': 'Watson Dirt Sand & Gravel Pit Inc',
#   'State': 'LA',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '4103429',
#   'Mine Name': 'Y B Mine',
#   'Operature': 'Y B Dirt & Loam',
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'},
#  {'CM': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'ID': '4103264',
#   'Mine Name': 'Yarbrough Dirt Pit #1',
#   'Operature': 'Yarbrough Dirt Pit Inc',
#   'State': 'TX',
#   'Status': 'Abandoned',
#   'Type': 'Surface'}]

# %% [markdown]
# ### Save that to a CSV

# %%
import pandas as pd

df = pd.DataFrame(dirt)

df.head()
df.to_csv("dirt.csv", index = False)

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.

# %%
df_dirt = pd.read_csv("dirt.csv")
df_dirt.head()
# Out:
#   CM                     Commodity       ID  \
# 0  M     Crushed, Broken Stone NEC  3503598
# 1  M  Construction Sand and Gravel   502030
# 2  M  Construction Sand and Gravel  4801789
# 3  C             Coal (Bituminous)  4201449
# 4  C             Coal (Bituminous)  4201450
#
#                            Mine Name                       Operature State  \
# 0                Newberg Rock & Dirt             Newberg Rock & Dirt    OR
# 1  Allied Dirt Moving Co Pit & Plant      Allied Dirt Moving Company    CO
# 2     AM Dirtworks & Aggregate Sales  AM Dirtworks & Aggregate Sales    ND
# 3        Unit Train Loading Facility        Atlas-Dirty Devil Mining    UT
# 4  Blackie Surface Mine & Prep Plant        Atlas-Dirty Devil Mining    UT
#
#          Status      Type
# 0        Active   Surface
# 1     Abandoned   Surface
# 2  Intermittent   Surface
# 3     Abandoned  Facility
# 4     Abandoned   Surface
