# %% [markdown]
# # Scraping Maryland Business Licenses with Selenium
#
# Maryland has a [great portal](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp) for searching business licenses, but the only problem is you have to check a box in order to get in.
#
# 1. Try to visit [the public search page](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp)
# 2. Get redirected to a "I agree to this" page. Click that you've read the disclaimer, click Enter the Site.
# 3. Click "Search License Records" down at the bottom of the page
# 4. You're now on the search page! From the "Jurisdiction" dropdown, select "Statewide"
# 5. In the "Trade Name" field, type "Vap%" to try to find vape shops
# 6. Click "Next" in the bottom right-hand corner to go to the next page
# 7. Click "Click for detail" to see the details for a specific business license.
#
# That's a lot of stuff! **Let's get to work.**

# %% [markdown]
# ## Preparation
#
# ### When you search for a business license, what URL should Selenium try to visit first?

# %%
from selenium import webdriver
driver = webdriver.Chrome()
driver.get("https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=uYnr%2BUU26hU%3D")

# %% [markdown]
# **It isn't going to work, though! It's going to redirect to that intro page.** You can use *Incognito mode* to go back through the "Check the box, etc" series of pages.
#
# ### How will you identify the checkbox to check it?
#
# Selenium can find elements by:
#
# - name
# - Class
# - ID
# - CSS selector (**ASK ME WHAT THIS IS** if you don't know)
# - XPath (**ASK ME WHAT THIS IS** because you definitely don't know)
# - Link text
# - Partial link text
#
# So in other words, what's unique about this element?
#
# - *TIP: I have a secret awesome way to do this, but you have to ask.*

# %%
checkbox = driver.find_element_by_xpath('//*[@id="checkbox"]')
checkbox
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="390c121fcb9e99aaad5da9c80bf77daa", element="0.21200405325449223-1")>

# %% [markdown]
# ### How will you identify the button to select it, or the form to submit it?
#
# Selenium can submit forms by either
#
# - Selecting the form and using `.submit()`, or
# - Selecting the button and using `.click()`
#
# You only need to be able to get **one, not both.**

# %%
Enter_the_Site = driver.find_element_by_xpath('/html/body/table/tbody/tr[7]/td/form/div/input[2]')
Enter_the_Site.click()

# %% [markdown]
# ### Once you're on the next page, how will you click the "SEARCH LICENSE RECORDS" link or follow its URL?

# %%
Liscence_records = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[6]/td[2]/a[2]')
Liscence_records.click()

# %% [markdown]
# ### Now you're on the form page. How do you pick "Statewide" for the jurisdiction dropdown?

# %%
from selenium.webdriver.support.ui import Select
select = Select(driver.find_element_by_xpath('//*[@id="slcJurisdiction"]'))
select.select_by_visible_text("Statewide")

# %% [markdown]
# ### How do you type "vap%" into the Trade Name field?

# %%
trade_name = driver.find_element_by_xpath('//*[@id="txtTradeName"]')
trade_name.send_keys("vap%")

# %% [markdown]
# ### How do you click the submit button or submit the form?

# %%
submit = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/form/table/tbody/tr[14]/td/input[1]')
submit.click()

# %% [markdown]
# ### How can you find and click the 'Next' button on the search results page?

# %%
while True:
    ## This will run, until it gets an error and then it will break. 
    ## IF YOU DON'T WRITE BREAK IT WILL RUN FOREVER!!!!
    try:
        next_button = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[3]/a/nobr')
        next_button.click()
    except:
        break

# %% [markdown]
# # Okay, let's scrape!
#
# ### Use Selenium to search for vape shops statewide, and then click through until it reaches the last page.
#
# Don't scrape yet!

# %%
## I did this above

# %% [markdown]
# ### Use Selenium to scrape the first page of search results for vape shops statewide (well, we'll try).
#
# - *TIP: You can find elements/text using Selenium, or use BeautifulSoup with `doc = BeautifulSoup(driver.page_source)`*
#
# I've included some BeautifulSoup code that might be helpful. If you use it, **ask me how I made it.** It's important.

# %%
# IF YOU ARE USING BEAUTIFULSOUP, HERE IS SOME SAMPLE CODE
# IF YOU USE THIS CODE, ASK ME HOW I MADE IT. IT'S IMPORTANT.
from bs4 import BeautifulSoup
doc = BeautifulSoup(driver.page_source, "html.parser")
business_headers = doc.find_all('tr',class_='searchfieldtitle')
len(business_headers)
# Out:
# 5

# %%
# You'll probably need to find specific tds inside
# of the rows instead of looking at the whole thing.
for header in business_headers:
    rows = header.find_next_siblings('tr')
    print("HEADER is", header.text.strip())
    if header.find("a"):
        links = header.find("a")["href"]
        print("link is", links.strip())
    else:
        links = "none"
        print(links)
    print("ROW 0 IS", rows[0].text.strip())
    print("ROW 1 IS", rows[1].text.strip())
    print("ROW 2 IS", rows[2].text.strip())
    print("ROW 3 IS", rows[3].text.strip())
    print("----")
# Out:
# HEADER is 1.
# VAPE IT STORE II
# link is pbLicenseDetail.jsp?owi=QBwCBqE3UH0%3D
# ROW 0 IS AMIN NARGIS
# Lic. Status: Issued
# ROW 1 IS 1015 S SALISBURY BLVD
# License: 22173808
# ROW 2 IS SALISBURY, MD 21801
# Issued Date: 4/27/2017
# ROW 3 IS Wicomico County
# ----
# HEADER is 2.
# VAPE IT STORE I
# link is pbLicenseDetail.jsp?owi=gXYTVqpDCfA%3D
# ROW 0 IS AMIN NARGIS
# Lic. Status: Issued
# ROW 1 IS 1724 N SALISBURY BLVD UNIT 2
# License: 22173807
# ROW 2 IS SALISBURY, MD 21801
# Issued Date: 4/27/2017
# ROW 3 IS Wicomico County
# ----
# HEADER is 3.
# VAPEPAD THE
# link is pbLicenseDetail.jsp?owi=vbuPTC20I14%3D
# ROW 0 IS ANJ DISTRIBUTIONS LLC
# Lic. Status: Issued
# ROW 1 IS 2299 JOHNS HOPKINS ROAD
# License: 02104436
# ROW 2 IS GAMBRILLS, MD 21054
# Issued Date: 4/05/2017
# ROW 3 IS Anne Arundel County
# ----
# HEADER is 4.
# VAPE FROG
# link is pbLicenseDetail.jsp?owi=xs9NlmRQHEs%3D
# ROW 0 IS COX TRADING COMPANY L L C
# Lic. Status: Issued
# ROW 1 IS 110 S. PINEY RD
# License: 17165957
# ROW 2 IS CHESTER, MD 21619
# Issued Date: 5/31/2017
# ROW 3 IS Queen Anne's County
# ----
# HEADER is 5.
# VAPE FROG
# Pending *
# none
# ROW 0 IS COX TRADING LLC
# Lic. Status: Pending
# ROW 1 IS 346 RITCHIE HIGHWAY
# ROW 2 IS SEVERNA PARK, MD 21146
# ROW 3 IS Anne Arundel County
# ----

# %% [markdown]
# ### Save these into `vape-results.csv`

# %%
list_1 = []
for header in business_headers:
    dictionary = {}
    rows = header.find_next_siblings('tr')
    header_1 = header.find_all("td")[1].text.strip().replace("\n", "")
    if header_1:
        print(header_1)
        dictionary["Header"] = header_1
    if header.find("a"):
        links = header.find("a")["href"]
        print("link is", links.strip())
        dictionary["link"] = links
    else:
        links = "none"
        print(links)
        dictionary["link"] = links
    License = rows[0]("td")[2].text.strip().replace("\n", "")
    if Status:
        print(License)
        dictionary["License"] = License
    Company = rows[0]("td")[1].text.strip().replace("\n", "")
    if Company:
        dictionary["Company"] = Company
    License_number = rows[1]("td")[2].text.strip().replace("\n", "")
    if License_number:
        print(License_number)
        dictionary["License_number"] = License_number
    Address = rows[2]("td")[1].text.strip().replace("\n", "")
    if Address:
        print(Address)
        dictionary["Address"] = Address
    Issued_Date = rows[2]("td")[2].text.strip().replace("\n", "")
    if Issued_Date:
        dictionary["Issued_Date"] = Issued_Date
    county = rows[3]("td")[1].text.strip().replace("\n", "")
    if county:
        print(county)
        dictionary["county"] = county
    list_1.append(dictionary)
# Out:
# VAPE DOJO
# none
# Lic. Status: Pending
# BALTIMORE, MD 21220
# Baltimore County
# VAPEZ YARDHOUSE
# none
# Lic. Status: Pending
# WALDORF, MD 20603
# Charles County

# %%
list_1
# Out:
# [{'Address': 'BALTIMORE, MD 21220',
#   'Company': 'WALKER TRADING COMPANY INC',
#   'Header': 'VAPE DOJO',
#   'License': 'Lic. Status: Pending',
#   'county': 'Baltimore County',
#   'link': 'none'},
#  {'Address': 'WALDORF, MD 20603',
#   'Company': 'YARKHOUSE EMPIRE INC',
#   'Header': 'VAPEZ YARDHOUSE',
#   'License': 'Lic. Status: Pending',
#   'county': 'Charles County',
#   'link': 'none'}]

# %%
import pandas as pd

df = pd.DataFrame(list_1)

df.to_csv("vap-results.csv", index = False)

# %%
df.head()
# Out:
#                   Address                    Company            Header  \
# 0     SALISBURY, MD 21801                AMIN NARGIS   VAPE IT STORE I
# 1     SALISBURY, MD 21801                AMIN NARGIS  VAPE IT STORE II
# 2     GAMBRILLS, MD 21054      ANJ DISTRIBUTIONS LLC       VAPEPAD THE
# 3       CHESTER, MD 21619  COX TRADING COMPANY L L C         VAPE FROG
# 4  SEVERNA PARK, MD 21146            COX TRADING LLC         VAPE FROG
#
#               Issued_Date               License     License_number  \
# 0  Issued Date: 4/27/2017   Lic. Status: Issued  License: 22173807
# 1  Issued Date: 4/27/2017   Lic. Status: Issued  License: 22173808
# 2  Issued Date: 4/05/2017   Lic. Status: Issued  License: 02104436
# 3  Issued Date: 5/31/2017   Lic. Status: Issued  License: 17165957
# 4                     NaN  Lic. Status: Pending                NaN
#
#                 county                                      link
# 0      Wicomico County  pbLicenseDetail.jsp?owi=HaO01%2BcCwdw%3D
# 1      Wicomico County    pbLicenseDetail.jsp?owi=JqwqHzniaE8%3D
# 2  Anne Arundel County    pbLicenseDetail.jsp?owi=5HpqsTJaRoc%3D
# 3  Queen Anne's County    pbLicenseDetail.jsp?owi=dJPyqahUZM8%3D
# 4  Anne Arundel County                                      none

# %% [markdown]
# ### Open `vape-results.csv` to make sure there aren't any extra weird columns

# %%
df_vap = pd.read_csv("vap-results.csv")
df_vap.head()
# Out:
#                   Address                    Company            Header  \
# 0     SALISBURY, MD 21801                AMIN NARGIS   VAPE IT STORE I
# 1     SALISBURY, MD 21801                AMIN NARGIS  VAPE IT STORE II
# 2     GAMBRILLS, MD 21054      ANJ DISTRIBUTIONS LLC       VAPEPAD THE
# 3       CHESTER, MD 21619  COX TRADING COMPANY L L C         VAPE FROG
# 4  SEVERNA PARK, MD 21146            COX TRADING LLC         VAPE FROG
#
#               Issued_Date               License     License_number  \
# 0  Issued Date: 4/27/2017   Lic. Status: Issued  License: 22173807
# 1  Issued Date: 4/27/2017   Lic. Status: Issued  License: 22173808
# 2  Issued Date: 4/05/2017   Lic. Status: Issued  License: 02104436
# 3  Issued Date: 5/31/2017   Lic. Status: Issued  License: 17165957
# 4                     NaN  Lic. Status: Pending                NaN
#
#                 county                                      link
# 0      Wicomico County  pbLicenseDetail.jsp?owi=HaO01%2BcCwdw%3D
# 1      Wicomico County    pbLicenseDetail.jsp?owi=JqwqHzniaE8%3D
# 2  Anne Arundel County    pbLicenseDetail.jsp?owi=5HpqsTJaRoc%3D
# 3  Queen Anne's County    pbLicenseDetail.jsp?owi=dJPyqahUZM8%3D
# 4  Anne Arundel County                                      none

# %% [markdown]
# ## Use Selenium to scrape ALL pages of results, save the results into `vape-results-all.csv`.

# %%
list_1 = []

while True:
    ## This will run, until it gets an error and then it will break. 
    ## IF YOU DON'T WRITE BREAK IT WILL RUN FOREVER!!!!
    doc = BeautifulSoup(driver.page_source, "html.parser")
    business_headers = doc.find_all('tr',class_='searchfieldtitle')
    for header in business_headers:
        dictionary = {}
        rows = header.find_next_siblings('tr')
        header_1 = header.find_all("td")[1].text.strip().replace("\n", "")
        if header_1:
            print(header_1)
            dictionary["Header"] = header_1
        if header.find("a"):
            links = header.find("a")["href"]
            print("link is", links.strip())
            dictionary["link"] = links
        else:
            links = "none"
            print(links)
            dictionary["link"] = links
        License = rows[0]("td")[2].text.strip().replace("\n", "")
        if Status:
            print(License)
            dictionary["License"] = License
        Company = rows[0]("td")[1].text.strip().replace("\n", "")
        if Company:
            dictionary["Company"] = Company
        License_number = rows[1]("td")[2].text.strip().replace("\n", "")
        if License_number:
            print(License_number)
            dictionary["License_number"] = License_number
        Address = rows[2]("td")[1].text.strip().replace("\n", "")
        if Address:
            print(Address)
            dictionary["Address"] = Address
        Issued_Date = rows[2]("td")[2].text.strip().replace("\n", "")
        if Issued_Date:
            dictionary["Issued_Date"] = Issued_Date
        county = rows[3]("td")[1].text.strip().replace("\n", "")
        if county:
            print(county)
            dictionary["county"] = county
        list_1.append(dictionary)
    try:
        next_button = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[3]/a/nobr')
        next_button.click()
    except:
        break
# Out:
# VAPE IT STORE I
# link is pbLicenseDetail.jsp?owi=HaO01%2BcCwdw%3D
# Lic. Status: Issued
# License: 22173807
# SALISBURY, MD 21801
# Wicomico County
# VAPE IT STORE II
# link is pbLicenseDetail.jsp?owi=JqwqHzniaE8%3D
# Lic. Status: Issued
# License: 22173808
# SALISBURY, MD 21801
# Wicomico County
# VAPEPAD THE
# link is pbLicenseDetail.jsp?owi=5HpqsTJaRoc%3D
# Lic. Status: Issued
# License: 02104436
# GAMBRILLS, MD 21054
# Anne Arundel County
# VAPE FROG
# link is pbLicenseDetail.jsp?owi=dJPyqahUZM8%3D
# Lic. Status: Issued
# License: 17165957
# CHESTER, MD 21619
# Queen Anne's County
# VAPE FROG
# none
# Lic. Status: Pending
# SEVERNA PARK, MD 21146
# Anne Arundel County
# VAPE LOFT (THE)
# link is pbLicenseDetail.jsp?owi=SvQ4nSFpTDI%3D
# Lic. Status: Issued
# License: 02102408
# EDGEWATER, MD 21037
# Anne Arundel County
# VAPE N CIGAR
# link is pbLicenseDetail.jsp?owi=T%2BxQyHhiO0w%3D
# Lic. Status: Issued
# License: 13141786
# COLUMBIA, MD 21045
# Howard County
# VAPE DOJO
# link is pbLicenseDetail.jsp?owi=ZHw1rXxdIKM%3D
# Lic. Status: Issued
# License: 06126253
# WESTMINSTER, MD 21157
# Carroll County
# VAPE HAVEN
# none
# Lic. Status: Pending
# CHARLOTTE HALL, MD 20622
# St. Mary's County
# VAPE BIRD
# link is pbLicenseDetail.jsp?owi=SgXULdNMcGs%3D
# Lic. Status: Issued
# License: 17166688
# STEVENSVILLE, MD 21666
# Queen Anne's County
# VAPE FROG
# none
# Lic. Status: Pending
# CHESTER, MD 21619
# Queen Anne's County
# VAPORS LOUNGE
# link is pbLicenseDetail.jsp?owi=ZqS8dUM4fO8%3D
# Lic. Status: Issued
# License: 18167503
# MECHANICSVILLE, MD 20659
# St. Mary's County
# VAPORS LOUNGE
# none
# Lic. Status: Pending
# LA PLATA, MD 20646
# Charles County
# VAPIST MD
# none
# Lic. Status: Pending
# CAMP SPRINGS, MD 20748
# St. Mary's County
# VAPIST MD LLC
# none
# Lic. Status: Pending
# CAMP SPRINGS, MD 20748
# Prince George's County
# VAPERTETMD
# none
# Lic. Status: Pending
# GLEN BURNIE, MD 21060
# Anne Arundel County
# VAPERTEKMD
# none
# Lic. Status: Pending
# ELKRIDGE, MD 21075
# Howard County
# VAPORIOT
# none
# Lic. Status: Pending
# BALTIMORE, MD 21222
# Baltimore County
# VAPE PLUS
# link is pbLicenseDetail.jsp?owi=6nabwE1%2B1X4%3D
# Lic. Status: Issued
# License: 23178140
# POCOMOKE CITY, MD 21851
# Worcester County
# VAPE  SOCIAL
# link is pbLicenseDetail.jsp?owi=aNMbmFm%2FdLY%3D
# Lic. Status: Issued
# License: 15155429
# GAITHERSBURG, MD 20877
# Montgomery County
# VAPE JUNGLE
# link is pbLicenseDetail.jsp?owi=8O3eoIQLOl0%3D
# Lic. Status: Issued
# License: 08131285
# WALDORF, MD 20601
# Charles County
# VAPE TIME
# none
# Lic. Status: Pending
# NOTTINGHAM, MD 21236
# Baltimore County
# VAPEBAR EXPESS
# none
# Lic. Status: Pending
# WALDORF, MD 20603
# Charles County
# VAPOR 99
# link is pbLicenseDetail.jsp?owi=p0fF8I2ELB8%3D
# Lic. Status: Issued
# License: 16165362
# BOWIE, MD 20716
# Prince George's County
# VAPOR ALLEY
# link is pbLicenseDetail.jsp?owi=rTN9h5PIHEc%3D
# Lic. Status: Issued
# License: 20170900
# EASTON, MD 21601
# Talbot County
# VAPOR EMPORIUM
# link is pbLicenseDetail.jsp?owi=iTIXTHMlXxU%3D
# Lic. Status: Issued
# License: 10135432
# NEW MARKET, MD 21774
# Frederick County
# VAPOR VILLA
# link is pbLicenseDetail.jsp?owi=OkzjcDRFEIA%3D
# Lic. Status: Issued
# License: 03121958
# BALTIMORE, MD 21227
# Baltimore County
# VAPOR VILLA
# link is pbLicenseDetail.jsp?owi=SGpifdVM%2F0g%3D
# Lic. Status: Issued
# License: 03121959
# CATONSVILLE, MD 21228
# Baltimore County
# VAPE DOJO
# link is pbLicenseDetail.jsp?owi=EjhxlJbeEok%3D
# Lic. Status: Issued
# License: 12140135
# BEL AIR, MD 21014
# Harford County
# VAPE DOJO
# none
# Lic. Status: Pending
# BALTIMORE, MD 21220
# Baltimore County
# VAPE DOJO
# link is pbLicenseDetail.jsp?owi=ul85giMtiQ0%3D
# Lic. Status: Issued
# License: 13144108
# ELLICOTT CITY, MD 21042
# Howard County
# VAPEZ YARDHOUSE
# none
# Lic. Status: Pending
# WALDORF, MD 20603
# Charles County

# %%
list_1
# Out:
# [{'Date': 'SALISBURY, MD 21801Issued Date: 4/27/2017',
#   'Header': '1.VAPE IT STORE II',
#   'License': '1015 S SALISBURY BLVDLicense: 22173808',
#   'Status': 'AMIN NARGISLic. Status: Issued',
#   'county': 'Wicomico County',
#   'link': 'pbLicenseDetail.jsp?owi=QBwCBqE3UH0%3D'},
#  {'Date': 'SALISBURY, MD 21801Issued Date: 4/27/2017',
#   'Header': '2.VAPE IT STORE I',
#   'License': '1724 N SALISBURY BLVD UNIT 2License: 22173807',
#   'Status': 'AMIN NARGISLic. Status: Issued',
#   'county': 'Wicomico County',
#   'link': 'pbLicenseDetail.jsp?owi=gXYTVqpDCfA%3D'},
#  {'Date': 'GAMBRILLS, MD 21054Issued Date: 4/05/2017',
#   'Header': '3.VAPEPAD THE',
#   'License': '2299 JOHNS HOPKINS ROADLicense: 02104436',
#   'Status': 'ANJ DISTRIBUTIONS LLCLic. Status: Issued',
#   'county': 'Anne Arundel County',
#   'link': 'pbLicenseDetail.jsp?owi=vbuPTC20I14%3D'},
#  {'Date': 'CHESTER, MD 21619Issued Date: 5/31/2017',
#   'Header': '4.VAPE FROG',
#   'License': '110 S. PINEY RDLicense: 17165957',
#   'Status': 'COX TRADING COMPANY L L CLic. Status: Issued',
#   'county': "Queen Anne's County",
#   'link': 'pbLicenseDetail.jsp?owi=xs9NlmRQHEs%3D'},
#  {'Date': 'SEVERNA PARK, MD 21146',
#   'Header': '5.VAPE FROGPending *',
#   'License': '346 RITCHIE HIGHWAY',
#   'Status': 'COX TRADING LLCLic. Status: Pending',
#   'county': 'Anne Arundel County',
#   'link': 'none'},
#  {'Date': 'EDGEWATER, MD 21037Issued Date: 4/13/2017',
#   'Header': '6.VAPE LOFT (THE)',
#   'License': '185 MITCHELLS CHANCE RDLicense: 02102408',
#   'Status': 'DISBROW II EMERSON HARRINGTONLic. Status: Issued',
#   'county': 'Anne Arundel County',
#   'link': 'pbLicenseDetail.jsp?owi=gzJn%2BEn85fc%3D'},
#  {'Date': 'COLUMBIA, MD 21045Issued Date: 5/19/2017',
#   'Header': '7.VAPE N CIGAR',
#   'License': '7104 MINSTREL UNIT #7License: 13141786',
#   'Status': 'DISCOUNT TOBACCO ESSEX LLCLic. Status: Issued',
#   'county': 'Howard County',
#   'link': 'pbLicenseDetail.jsp?owi=bP3ePZLBTko%3D'},
#  {'Date': 'WESTMINSTER, MD 21157Issued Date: 4/21/2017',
#   'Header': '8.VAPE DOJO',
#   'License': '330 ONE FORTY VILLAGE ROADLicense: 06126253',
#   'Status': 'FAIRGROUND VILLAGE LLCLic. Status: Issued',
#   'county': 'Carroll County',
#   'link': 'pbLicenseDetail.jsp?owi=MMtYSxakeOU%3D'},
#  {'Date': 'CHARLOTTE HALL, MD 20622',
#   'Header': '9.VAPE HAVENPending *',
#   'License': '29890 THREE NOTCH ROAD',
#   'Status': 'GRIMM JENNIFERLic. Status: Pending',
#   'county': "St. Mary's County",
#   'link': 'none'},
#  {'Date': 'STEVENSVILLE, MD 21666Issued Date: 4/13/2017',
#   'Header': '10.VAPE BIRD',
#   'License': '356 ROMANCOKE ROADLicense: 17166688',
#   'Status': 'HUTCH VAPES LLCLic. Status: Issued',
#   'county': "Queen Anne's County",
#   'link': 'pbLicenseDetail.jsp?owi=RcH%2FWCPW59o%3D'},
#  {'Date': 'CHESTER, MD 21619',
#   'Header': '11.VAPE FROGPending *',
#   'License': '110 S PINEY ROAD  STE 106',
#   'Status': 'HUTCHINS COX LLPLic. Status: Pending',
#   'county': "Queen Anne's County",
#   'link': 'none'},
#  {'Date': 'MECHANICSVILLE, MD 20659Issued Date: 5/17/2017',
#   'Header': '12.VAPORS LOUNGE',
#   'License': '28943 THREE NOTCH ROADLicense: 18167503',
#   'Status': 'JAMESON WILLIAMLic. Status: Issued',
#   'county': "St. Mary's County",
#   'link': 'pbLicenseDetail.jsp?owi=M2MY3f5GxR0%3D'},
#  {'Date': 'LA PLATA, MD 20646',
#   'Header': '13.VAPORS LOUNGEPending *',
#   'License': '6843 CRAIN HIGHWAY',
#   'Status': 'JAMESON WILLIAM ELic. Status: Pending',
#   'county': 'Charles County',
#   'link': 'none'},
#  {'Date': 'CAMP SPRINGS, MD 20748',
#   'Header': '14.VAPIST MDPending *',
#   'License': '6321 OLD BRANCH AVE',
#   'Status': 'JEFFERS MICHAELLic. Status: Pending',
#   'county': "St. Mary's County",
#   'link': 'none'},
#  {'Date': 'CAMP SPRINGS, MD 20748',
#   'Header': '15.VAPIST MD LLCPending *',
#   'License': '6321 OLD BRANCH AVE',
#   'Status': 'JEFFERS MICHAEL WLic. Status: Pending',
#   'county': "Prince George's County",
#   'link': 'none'},
#  {'Date': 'GLEN BURNIE, MD 21060',
#   'Header': '16.VAPERTETMDPending *',
#   'License': '7954 B AND A BLVD',
#   'Status': 'SHIN JENNY YLic. Status: Pending',
#   'county': 'Anne Arundel County',
#   'link': 'none'},
#  {'Date': 'ELKRIDGE, MD 21075',
#   'Header': '17.VAPERTEKMDPending *',
#   'License': '6325 WASHINGTON BLVD',
#   'Status': 'SHIN JENNY YOUNGLic. Status: Pending',
#   'county': 'Howard County',
#   'link': 'none'},
#  {'Date': 'BALTIMORE, MD 21222',
#   'Header': '18.VAPORIOTPending *',
#   'License': '3203 NORTH POINT RD',
#   'Status': 'TAYLOR TRAVISLic. Status: Pending',
#   'county': 'Baltimore County',
#   'link': 'none'},
#  {'Date': 'POCOMOKE CITY, MD 21851Issued Date: 5/05/2017',
#   'Header': '19.VAPE PLUS',
#   'License': '519 LINDEN AVENUE UNIT 6License: 23178140',
#   'Status': 'TRUE ENTERPRISE INCLic. Status: Issued',
#   'county': 'Worcester County',
#   'link': 'pbLicenseDetail.jsp?owi=hwxhaZ5Cpa0%3D'},
#  {'Date': 'GAITHERSBURG, MD 20877Issued Date: 4/18/2017',
#   'Header': '20.VAPE  SOCIAL',
#   'License': '16521 S FREDERICK AVELicense: 15155429',
#   'Status': 'VAPE  SOCIAL  LLCLic. Status: Issued',
#   'county': 'Montgomery County',
#   'link': 'pbLicenseDetail.jsp?owi=t9CRC6WiOJE%3D'},
#  {'Date': 'WALDORF, MD 20601Issued Date: 3/31/2017',
#   'Header': '21.VAPE JUNGLE',
#   'License': '2070 CRAIN HIGHWAY  UNIT FLicense: 08131285',
#   'Status': 'VAPE JUNGLE LLCLic. Status: Issued',
#   'county': 'Charles County',
#   'link': 'pbLicenseDetail.jsp?owi=7Ah9WuE5KDQ%3D'},
#  {'Date': 'NOTTINGHAM, MD 21236',
#   'Header': '22.VAPE TIMEPending *',
#   'License': '4130 E JOPPA RD UNIT 109',
#   'Status': 'VAPE TIME LLCLic. Status: Pending',
#   'county': 'Baltimore County',
#   'link': 'none'},
#  {'Date': 'WALDORF, MD 20603',
#   'Header': '23.VAPEBAR EXPESSPending *',
#   'License': '11110 MALL CIRCLE',
#   'Status': 'VAPEBAR EXPRESS LLCLic. Status: Pending',
#   'county': 'Charles County',
#   'link': 'none'},
#  {'Date': 'BOWIE, MD 20716Issued Date: 5/03/2017',
#   'Header': '24.VAPOR 99',
#   'License': '3524 CRAIN HWYLicense: 16165362',
#   'Status': 'VAPOR 99 LLCLic. Status: Issued',
#   'county': "Prince George's County",
#   'link': 'pbLicenseDetail.jsp?owi=DI4EsoOcQfU%3D'},
#  {'Date': 'EASTON, MD 21601Issued Date: 5/10/2017',
#   'Header': '25.VAPOR ALLEY',
#   'License': '8117 OCEAN GATEWAY UNIT #4License: 20170900',
#   'Status': 'VAPOR ALLEY LLCLic. Status: Issued',
#   'county': 'Talbot County',
#   'link': 'pbLicenseDetail.jsp?owi=zUFsUEwV%2BEY%3D'},
#  {'Date': 'NEW MARKET, MD 21774Issued Date: 4/14/2017',
#   'Header': '26.VAPOR EMPORIUM',
#   'License': '11717 OLD NATIONAL PIKELicense: 10135432',
#   'Status': 'VAPOR EMPORIUM MD LLCLic. Status: Issued',
#   'county': 'Frederick County',
#   'link': 'pbLicenseDetail.jsp?owi=Z0SfbToOPOM%3D'},
#  {'Date': 'BALTIMORE, MD 21227Issued Date: 4/12/2017',
#   'Header': '27.VAPOR VILLA',
#   'License': '1913 LANSDOWNE ROAD SUITE ELicense: 03121958',
#   'Status': 'VAPOR VILLA CORPLic. Status: Issued',
#   'county': 'Baltimore County',
#   'link': 'pbLicenseDetail.jsp?owi=WOUOPwxIaVs%3D'},
#  {'Date': 'CATONSVILLE, MD 21228Issued Date: 4/12/2017',
#   'Header': '28.VAPOR VILLA',
#   'License': '730 FREDERICK ROADLicense: 03121959',
#   'Status': 'VAPOR VILLA CORPLic. Status: Issued',
#   'county': 'Baltimore County',
#   'link': 'pbLicenseDetail.jsp?owi=rp2END7OpXw%3D'},
#  {'Date': 'BEL AIR, MD 21014Issued Date: 4/03/2017',
#   'Header': '29.VAPE DOJO',
#   'License': '138 N BOND STREETLicense: 12140135',
#   'Status': 'WALKER TRADING CO INCLic. Status: Issued',
#   'county': 'Harford County',
#   'link': 'pbLicenseDetail.jsp?owi=mw6upJG6e%2FU%3D'},
#  {'Date': 'ELLICOTT CITY, MD 21042Issued Date: 3/27/2017',
#   'Header': '30.VAPE DOJO',
#   'License': '3570 SAINT JOHNS LANE, SUITE 109License: 13144108',
#   'Status': 'WALKER TRADING COMPANY INCLic. Status: Issued',
#   'county': 'Howard County',
#   'link': 'pbLicenseDetail.jsp?owi=nT7KEDq121E%3D'},
#  {'Date': 'BALTIMORE, MD 21220',
#   'Header': '31.VAPE DOJOPending *',
#   'License': '11600 CROSSROAD CIR  STE E',
#   'Status': 'WALKER TRADING COMPANY INCLic. Status: Pending',
#   'county': 'Baltimore County',
#   'link': 'none'},
#  {'Date': 'WALDORF, MD 20603',
#   'Header': '32.VAPEZ YARDHOUSEPending *',
#   'License': '3315 PLAZA WAY',
#   'Status': 'YARKHOUSE EMPIRE INCLic. Status: Pending',
#   'county': 'Charles County',
#   'link': 'none'}]

# %%
df = pd.DataFrame(list_1)

df.to_csv("vap-results-all.csv", index = False)

# %%
df.head()
# Out:
#                   Address                    Company            Header  \
# 0     SALISBURY, MD 21801                AMIN NARGIS   VAPE IT STORE I
# 1     SALISBURY, MD 21801                AMIN NARGIS  VAPE IT STORE II
# 2     GAMBRILLS, MD 21054      ANJ DISTRIBUTIONS LLC       VAPEPAD THE
# 3       CHESTER, MD 21619  COX TRADING COMPANY L L C         VAPE FROG
# 4  SEVERNA PARK, MD 21146            COX TRADING LLC         VAPE FROG
#
#               Issued_Date               License     License_number  \
# 0  Issued Date: 4/27/2017   Lic. Status: Issued  License: 22173807
# 1  Issued Date: 4/27/2017   Lic. Status: Issued  License: 22173808
# 2  Issued Date: 4/05/2017   Lic. Status: Issued  License: 02104436
# 3  Issued Date: 5/31/2017   Lic. Status: Issued  License: 17165957
# 4                     NaN  Lic. Status: Pending                NaN
#
#                 county                                      link
# 0      Wicomico County  pbLicenseDetail.jsp?owi=HaO01%2BcCwdw%3D
# 1      Wicomico County    pbLicenseDetail.jsp?owi=JqwqHzniaE8%3D
# 2  Anne Arundel County    pbLicenseDetail.jsp?owi=5HpqsTJaRoc%3D
# 3  Queen Anne's County    pbLicenseDetail.jsp?owi=dJPyqahUZM8%3D
# 4  Anne Arundel County                                      none

# %%
df_vap_all = pd.read_csv("vap-results-all.csv")
df_vap_all.head()
# Out:
#                   Address                    Company            Header  \
# 0     SALISBURY, MD 21801                AMIN NARGIS   VAPE IT STORE I
# 1     SALISBURY, MD 21801                AMIN NARGIS  VAPE IT STORE II
# 2     GAMBRILLS, MD 21054      ANJ DISTRIBUTIONS LLC       VAPEPAD THE
# 3       CHESTER, MD 21619  COX TRADING COMPANY L L C         VAPE FROG
# 4  SEVERNA PARK, MD 21146            COX TRADING LLC         VAPE FROG
#
#               Issued_Date               License     License_number  \
# 0  Issued Date: 4/27/2017   Lic. Status: Issued  License: 22173807
# 1  Issued Date: 4/27/2017   Lic. Status: Issued  License: 22173808
# 2  Issued Date: 4/05/2017   Lic. Status: Issued  License: 02104436
# 3  Issued Date: 5/31/2017   Lic. Status: Issued  License: 17165957
# 4                     NaN  Lic. Status: Pending                NaN
#
#                 county                                      link
# 0      Wicomico County  pbLicenseDetail.jsp?owi=HaO01%2BcCwdw%3D
# 1      Wicomico County    pbLicenseDetail.jsp?owi=JqwqHzniaE8%3D
# 2  Anne Arundel County    pbLicenseDetail.jsp?owi=5HpqsTJaRoc%3D
# 3  Queen Anne's County    pbLicenseDetail.jsp?owi=dJPyqahUZM8%3D
# 4  Anne Arundel County                                      none
